# %%
import numpy as np
import scipy.stats as stats
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

sns.set_style('whitegrid')

# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline

# %%
import sys

# %%
df = pd.read_csv("/Users/tyronewilliams/Desktop/DSI-SF-4/curriculum/week-04/5.1-weekly-review/combine.csv")

# %%
df.head()
# Out:
#      id  Year             Name Position  HeightFeet  HeightInches  Weight  \
# 0  8984  2013  Quanterus Smith       DE           6           5.0     250
# 1  9002  2013       Abry Jones       DT           6           3.0     313
# 2  9004  2013     Bennie Logan       DT           6           2.0     309
# 3  9012  2013      John Boyett       FS           5          10.0     204
# 4  9018  2013    Bacarri Rambo       FS           6           0.0     211
#
#     Arms   Hands  FortyYD    ...     Bench  Round           College     Pick  \
# 0  33.25  10.375      0.0    ...         0      5  Western Kentucky  13(146)
# 1  35.00   9.750      0.0    ...        30      0               NaN      NaN
# 2  34.00  10.250      0.0    ...        30      3               LSU    5(67)
# 3  30.50   8.500      0.0    ...        27      6            Oregon  24(192)
# 4  31.00   9.250      0.0    ...        17      6           Georgia  23(191)
#
# ...

# %%
df.describe()
# Out:
#                  id         Year   HeightFeet  HeightInches       Weight  \
# count   4625.000000  4625.000000  4625.000000   4625.000000  4625.000000
# mean   11371.059459  2006.584432     5.804541      4.391459   245.638054
# std     1523.180179     4.737971     0.396597      3.276100    45.617970
# min     8962.000000  1999.000000     5.000000      0.000000   155.000000
# 25%    10118.000000  2002.000000     6.000000      2.000000   208.000000
# 50%    11274.000000  2007.000000     6.000000      4.000000   237.000000
# 75%    12430.000000  2011.000000     6.000000      6.000000   289.000000
# max    14926.000000  2014.000000     6.000000     11.875000   386.000000
#
#               Arms        Hands      FortyYD     TwentyYD        TenYD  \
# count  4625.000000  4625.000000  4625.000000  4625.000000  4625.000000
# mean      8.172169     2.409243     4.662009     0.078867     0.138141
# std      14.120348     4.164665     0.848535     0.446677     0.450521
# ...

# %%
#Average weight, hieght(total), and bench press per position

# %%
df["Height"] = df["HeightFeet"]*12 + df["HeightInches"]
df.groupby("Position")[["Height","Weight", "Bench"]].mean()
# Out:
#              Height      Weight      Bench
# Position
# C         75.416667  307.166667  23.000000
# CB        71.244814  192.622271  11.912664
# DE        75.844388  267.931122  20.045918
# DT        75.088825  305.223496  23.730659
# FB        72.858586  245.060606  19.888889
# FS        72.807107  204.862944  14.340102
# ILB       73.632075  242.377358  19.047170
# K         71.750000  187.250000   0.000000
# LS        75.000000  258.000000   0.000000
# NT        73.500000  323.250000  21.750000
# OC        75.333333  302.515152  24.098485
# OG        76.084416  314.454545  22.051948
# OLB       73.931751  240.002967  19.459941
# OT        77.718157  316.707317  21.002710
# P         75.400000  219.800000   4.600000
# QB        74.912197  222.245675   0.937716
# RB        70.769254  213.372038  16.014218
# SS        72.352273  210.801136  15.204545
# TE        76.371324  255.022059  17.878676
# WR        72.911627  200.930153   6.114140

# %%
#by year, find the fastest 10yrd and heaviest player (include name)

# %%
fast = df[df["TenYD"] != 0]
fast = fast[["Year","Name", "TenYD"]]
fastest = fast.groupby("Year")["TenYD"].min()
# Out:
# Year
# 1999    1.47
# 2000    1.48
# 2001    1.55
# 2002    1.53
# 2003    1.55
# 2004    1.59
# 2005    1.53
# 2006    1.48
# 2007    1.43
# 2008    1.44
# 2009    1.43
# 2010    1.40
# 2011    1.50
# 2012    1.45
# 2013    1.43
# Name: TenYD, dtype: float64
