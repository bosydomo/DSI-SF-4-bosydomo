# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 15px; height: 80px">
#
# # Project 2
#
# ### Exploratory Data Analysis (EDA)
#
# ---
#
# This project is focused on exploratory data analysis (EDA). EDA is an essential part of the data science analysis pipeline. Failure to perform EDA before modeling is almost guaranteed to lead to pitfalls and faulty conclusions. What you do in this project are good practices for all projects going forward, especially those beyond this class!
#
# Problems 1 thru 6 use a small dataset on state SAT scores.
#
# Problems 7 thru 12 use a fraction of the Iowa Liquor Sales dataset (described in more detail in question 7).
#
# ---
#
# This project includes a variety of plotting problems. Much of the plotting code will be left up to you to find either in the lecture notes, or if not there, online. There are massive amounts of code snippets either in documentation or sites like stackoverflow that have almost certainly done what you are trying to do.
#
# **Get used to using google for finding code!** You will be using it every single day as a data scientist, especially for visualization and plotting.
#
# #### Package imports

# %%
import numpy as np
import scipy.stats as stats
import csv
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt


# this line tells jupyter notebook to put the plots in the notebook rather than saving them to file.
# %matplotlib inline

# this line makes plots prettier on mac retina screens. If you don't have one it shouldn't do anything.
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 1. Load the `sat_scores.csv` dataset and describe it
#
# ---
#
# You should replace the placeholder path to the `sat_scores.csv` dataset below with your specific path to the file.
#
# ### 1.1 Load the file with the `csv` module and put in dictionary format.
#
# The dictionary format for data will be keys as the column names/headers, and values as the row values for that column.
#
# Toy example:
# ```python
# data = {
#     'column1':[0,1,2,3],
#     'column2':['a','b','c','d']
#     }
# ```

# %%
sat_filepath = '/Users/tyronewilliams/Desktop/DSI-SF-4/datasets/state_sat_scores/sat_scores.csv'

# %%
sat = pd.read_csv(sat_filepath)

# %% [markdown]
# ### 1.2 Make a pandas DataFrame object with the sat dictionary and also with the pandas `.read_csv()` function
#
# Compare the DataFrames using the `.dtypes` attribute in the DataFrame objects. What is the difference between loading from file and inputting this dictionary (if any)?

# %%
sat.dtypes
# Out:
# State     object
# Rate       int64
# Verbal     int64
# Math       int64
# dtype: object

# %% [markdown]
# If you did not convert the string column values to float in your dictionary, the columns in the DataFrame are of type `object` (which are string values).

# %% [markdown]
# ### 1.3 Look at the first ten rows of the DataFrame and describe what the data appears to be.
#
# From now on, use the DataFrame loaded from the file using the `.read_csv()` function.
#
# Use the `.head(num)` built-in DataFrame function, where `num` is the number of rows to print out.
#
# You are not given a "codebook" with this data, so you will have to make some (very minor) inference.

# %%
sat.head(10)
# Out:
#   State  Rate  Verbal  Math
# 0    CT    82     509   510
# 1    NJ    81     499   513
# 2    MA    79     511   515
# 3    NY    77     495   505
# 4    NH    72     520   516
# 5    RI    71     501   499
# 6    PA    71     500   499
# 7    VT    69     511   506
# 8    ME    69     506   500
# 9    VA    68     510   501

# %%
sat.Rate.describe()
# Out:
# count    52.000000
# mean     37.153846
# std      27.301788
# min       4.000000
# 25%       9.000000
# 50%      33.500000
# 75%      63.500000
# max      82.000000
# Name: Rate, dtype: float64

# %%
sat.head()
# Out:
#   State  Rate  Verbal  Math
# 0    CT    82     509   510
# 1    NJ    81     499   513
# 2    MA    79     511   515
# 3    NY    77     495   505
# 4    NH    72     520   516

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 2. Create a "data dictionary" based on the data
#
# ---
#
# A data dictionary is an object that describes your data. This should contain the name of each variable (column), the type of the variable, your description of what the variable is, and the shape (rows and columns) of the entire dataset.

# %%
sat.dtypes
sat_dictionary = {"State": " State of SAT","Rate":"College eligible pass rate", "Verbal":"English profeciency score",
                  "Math":"Math profeciency score"}

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 3. Plot the data using seaborn
#
# ---
#
# ### 3.1 Using seaborn's `distplot`, plot the distributions for each of `Rate`, `Math`, and `Verbal`
#
# Set the keyword argument `kde=False`. This way you can actually see the counts within bins. You can adjust the number of bins to your liking.
#
# [Please read over the `distplot` documentation to learn about the arguments and fine-tune your chart if you want.](https://stanford.edu/~mwaskom/software/seaborn/generated/seaborn.distplot.html#seaborn.distplot)

# %%
sns.distplot(sat["Rate"], kde =False, bins=10)

# %% [markdown]
# ### 3.2 Using seaborn's `pairplot`, show the joint distributions for each of `Rate`, `Math`, and `Verbal`
#
# Explain what the visualization tells you about your data.
#
# [Please read over the `pairplot` documentation to fine-tune your chart.](https://stanford.edu/~mwaskom/software/seaborn/generated/seaborn.pairplot.html#seaborn.pairplot)

# %%
sns.pairplot(data =sat)

# %%
#Shows a scatter of each data set against each other which can give us ideas into possible 
#correlations between variables as well as the quantity of scores in each given category along the diagonal

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 4. Plot the data using built-in pandas functions.
#
# ---
#
# Pandas is very powerful and contains a variety of nice, built in plotting functions for your data. Read the documentation here to overview and understand the capabilities:
#
# http://pandas.pydata.org/pandas-docs/stable/visualization.html
#
# ### 4.1 Plot a stacked histogram with `Verbal` and `Math` using pandas

# %%
sns.set_style("white")
sns.set_context({"figure.figsize": (24, 10)})
sat_verbal = sat["Verbal"]
sat_math = sat["Math"]
sat_rate = sat["Rate"]
plt.hist([sat_math,sat_verbal], stacked=True)
# Out:
# ([array([  1.,   0.,   2.,  10.,  13.,   3.,   9.,   5.,   4.,   5.]),
#   array([  1.,   0.,   5.,  21.,  23.,   8.,  15.,  13.,  11.,   7.])],
#  array([ 439. ,  455.4,  471.8,  488.2,  504.6,  521. ,  537.4,  553.8,
#          570.2,  586.6,  603. ]),
#  <a list of 2 Lists of Patches objects>)

# %% [markdown]
# ### 4.2 Plot `Verbal` and `Math` on the same chart using boxplots (pandas or seaborn)
#
# What are the benefits of using a boxplot as compared to a scatterplot or a histogram?
#
# What's wrong with plotting a box-plot of `Rate` on the same chart as `Math` and `Verbal`?

# %%
#the problem is that the data is to sparsley populated to get an accurate view of the data. 
#Cannot get a good idea of the scale when looking at smaller data points

# %%
sns.boxplot(sat_verbal, sat_math )

# %% [markdown]
# <img src="http://imgur.com/xDpSobf.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ### 4.3 Plot `Verbal`, `Math`, and `Rate` appropriately on the same boxplot chart (pandas or seaborn)
#
# Think about how you might change the variables so that they would make sense on the same chart. Explain your rationale for the choices on the chart. You should strive to make the chart as intuitive as possible.

# %%
fig, ax = plt.subplots(1,1, figsize=(12,6))



ax.boxplot([sat_math, sat_verbal])

#Here we can see the box plots with the min value, max value and the corresponding quartiles for Math and Verbal
# #1 is Math scores, #2 is Verbal scores
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x12bd73d50>,
#   <matplotlib.lines.Line2D at 0x12bdb3690>],
#  'caps': [<matplotlib.lines.Line2D at 0x12bd8e690>,
#   <matplotlib.lines.Line2D at 0x12bd8ea90>,
#   <matplotlib.lines.Line2D at 0x12bdc27d0>,
#   <matplotlib.lines.Line2D at 0x12bdc2e10>],
#  'fliers': [<matplotlib.lines.Line2D at 0x12bdb32d0>,
#   <matplotlib.lines.Line2D at 0x12bdccad0>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x12bd8ee90>,
#   <matplotlib.lines.Line2D at 0x12bdcc490>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x12bd73e50>,
#   <matplotlib.lines.Line2D at 0x12bd8e290>,
#   <matplotlib.lines.Line2D at 0x12bdb3b10>,
#   <matplotlib.lines.Line2D at 0x12bdc2190>]}

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 5. Create and examine subsets of the data
#
# ---
#
# For these questions you will practice **masking** in pandas. Recall that masking uses conditional statements to select portions of your DataFrame (through boolean operations under the hood.)
#
# Remember the distinction between DataFrame indexing functions in pandas:
#
#     .iloc[row, col] : row and column are specified by index, which are integers
#     .loc[row, col]  : row and column are specified by string "labels" (boolean arrays are allowed; useful for rows)
#     .ix[row, col]   : row and column indexers can be a mix of labels and integer indices
#
# For detailed reference and tutorial make sure to read over the pandas documentation:
#
# http://pandas.pydata.org/pandas-docs/stable/indexing.html
#
#
#
# ### 5.1 Find the list of states that have `Verbal` scores greater than the average of `Verbal` scores across states
#
# How many states are above the mean? What does this tell you about the distribution of `Verbal` scores?

# %%
mean = sat["Verbal"].mean()
print mean
sat[sat["Verbal"] > mean]
# Out:
# 532.019230769
#    State  Rate  Verbal  Math
# 26    CO    31     539   542
# 27    OH    26     534   439
# 28    MT    23     539   539
# 30    ID    17     543   542
# 31    TN    13     562   553
# 32    NM    13     551   542
# 33    IL    12     576   589
# 34    KY    12     550   550
# 35    WY    11     547   545
# 36    MI    11     561   572
# 37    MN     9     580   589
# 38    KS     9     577   580
# 39    AL     9     559   554
# 40    NE     8     562   568
# 41    OK     8     567   561
# 42    MO     8     577   577
# 43    LA     7     564   562
# 44    WI     6     584   596
# 45    AR     6     562   550
# 46    UT     5     575   570
# 47    IA     5     593   603
# 48    SD     4     577   582
# 49    ND     4     592   599
# 50    MS     4     566   551

# %%
len(sat[sat["Verbal"] > mean]), len(sat["Verbal"])
#There are 24 states that are above the mean, looks like it could be normally dist'
# Out:
# (24, 52)

# %% [markdown]
# ### 5.2 Find the list of states that have `Verbal` scores greater than the median of `Verbal` scores across states
#
# How does this compare to the list of states greater than the mean of `Verbal` scores? Why?

# %%
median = sat["Verbal"].median()
median
sat[sat["Verbal"] > median]
# Out:
#    State  Rate  Verbal  Math
# 19    WA    53     527   527
# 26    CO    31     539   542
# 27    OH    26     534   439
# 28    MT    23     539   539
# 29    WV    18     527   512
# 30    ID    17     543   542
# 31    TN    13     562   553
# 32    NM    13     551   542
# 33    IL    12     576   589
# 34    KY    12     550   550
# 35    WY    11     547   545
# 36    MI    11     561   572
# 37    MN     9     580   589
# 38    KS     9     577   580
# 39    AL     9     559   554
# 40    NE     8     562   568
# 41    OK     8     567   561
# 42    MO     8     577   577
# 43    LA     7     564   562
# 44    WI     6     584   596
# 45    AR     6     562   550
# 46    UT     5     575   570
# 47    IA     5     593   603
# 48    SD     4     577   582
# 49    ND     4     592   599
# 50    MS     4     566   551

# %%
len(sat[sat["Verbal"] > median])
#There are 26 states thats are above the median, but its the median so the this tells us nothing other than 
#there are 52 data points(52 states). It does tell us that the median is greater than the mean and the data
#seems to be skewed to the right
# Out:
# 26

# %% [markdown]
# ### 5.3 Create a column that is the difference between the `Verbal` and `Math` scores
#
# Specifically, this should be `Verbal - Math`.

# %%
sat["Difference"] = sat["Verbal"] - sat["Math"]
sat["Difference"]
# Out:
# 0     -1
# 1    -14
# 2     -4
# 3    -10
# 4      4
# 5      2
# 6      1
# 7      5
# 8      6
# 9      9
# 10     2
# 11    -2
# 12    -6
# 13     2
# 14    -2
# 15    -2
# 16     8
# 17     0
# 18    -1
# 19     0
# 20    -6
# 21   -30
# 22     4
# 23   -19
# 24    -2
# 25    -6
# 26    -3
# 27    95
# 28     0
# 29    15
# 30     1
# 31     9
# 32     9
# 33   -13
# 34     0
# 35     2
# 36   -11
# 37    -9
# 38    -3
# 39     5
# 40    -6
# 41     6
# 42     0
# 43     2
# 44   -12
# 45    12
# 46     5
# 47   -10
# 48    -5
# 49    -7
# 50    15
# 51    -8
# Name: Difference, dtype: int64

# %% [markdown]
# ### 5.4 Create two new DataFrames showing states with the greatest difference between scores
#
# 1. Your first DataFrame should be the 10 states with the greatest gap between `Verbal` and `Math` scores where `Verbal` is greater than `Math`. It should be sorted appropriately to show the ranking of states.
# 2. Your second DataFrame will be the inverse: states with the greatest gap between `Verbal` and `Math` such that `Math` is greater than `Verbal`. Again, this should be sorted appropriately to show rank.
# 3. Print the header of both variables, only showing the top 3 states in each.

# %%
sat_verbal_greater = sat[sat["Verbal"] >sat["Math"]]
sat_verbal_greater.sort_values(by ="Difference", ascending=False).head(3)
# Out:
#    State  Rate  Verbal  Math  Difference
# 27    OH    26     534   439          95
# 29    WV    18     527   512          15
# 50    MS     4     566   551          15

# %%
sat_math_greater = sat[sat["Math"] >sat["Verbal"]]
sat_math_greater.sort_values(by ="Difference", ascending=True).head(3)
# Out:
#    State  Rate  Verbal  Math  Difference
# 21    HI    52     485   515         -30
# 23    CA    51     498   517         -19
# 1     NJ    81     499   513         -14

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 6. Examine summary statistics
#
# ---
#
# Checking the summary statistics for data is an essential step in the EDA process!
#
# ### 6.1 Create the correlation matrix of your variables (excluding `State`).
#
# What does the correlation matrix tell you?

# %%
sat.corr()
#Large Negative correlation between Rate & Verbal
#Large Negative correlation between Rate & Math
#Large Positive correlation between Verbal & Math
# Out:
#                 Rate    Verbal      Math  Difference
# Rate        1.000000 -0.886432 -0.773746   -0.101412
# Verbal     -0.886432  1.000000  0.899871    0.052600
# Math       -0.773746  0.899871  1.000000   -0.388219
# Difference -0.101412  0.052600 -0.388219    1.000000

# %% [markdown]
# ### 6.2 Use pandas'  `.describe()` built-in function on your DataFrame
#
# Write up what each of the rows returned by the function indicate.

# %%
sat.describe()

#Count - count of items in each column
#Mean - mean of each column
#Std - Standard deviation of each column
#Min - Minimum value in each column
#25% - Value at the 1st quartile
#50% - Value at the second quartile, median
#75% - Value at the third quartile
#Max - Maximum
# Out:
#             Rate      Verbal        Math  Difference
# count  52.000000   52.000000   52.000000   52.000000
# mean   37.153846  532.019231  531.500000    0.519231
# std    27.301788   33.236225   36.014975   15.729939
# min     4.000000  482.000000  439.000000  -30.000000
# 25%     9.000000  501.000000  504.000000   -6.000000
# 50%    33.500000  526.500000  521.000000    0.000000
# 75%    63.500000  562.000000  555.750000    4.250000
# max    82.000000  593.000000  603.000000   95.000000

# %% [markdown]
# <img src="http://imgur.com/xDpSobf.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ### 6.3 Assign and print the _covariance_ matrix for the dataset
#
# 1. Describe how the covariance matrix is different from the correlation matrix.
# 2. What is the process to convert the covariance into the correlation?
# 3. Why is the correlation matrix preferred to the covariance matrix for examining relationships in your data?

# %%
sat.cov()

# Covariance measusues how much each variable changes in relation to each other
# Correlation measures the effect
# Out:
#                   Rate       Verbal         Math  Difference
# Rate        745.387632  -804.355958  -760.803922  -43.552036
# Verbal     -804.355958  1104.646682  1077.147059   27.499623
# Math       -760.803922  1077.147059  1297.078431 -219.931373
# Difference  -43.552036    27.499623  -219.931373  247.430995

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 7. Load Iowa Liquor Sales dataset
#
# ---
#
# The state of Iowa provides many data sets on their website, including [this dataset](https://www.dropbox.com/sh/pf5n5sgfgiri3i8/AACkaMeL_i_WgZ00rpxOOcysa?dl=0) which contains transactions for all stores that have a class E liquor license. You can choose one of the following two scenarios.
#
# The data can also be found [directly on their website](https://data.iowa.gov/Economy/Iowa-Liquor-Sales/m3tr-qhgy), which allows you to explore it graphically and download it (though it doesn't work very well).
#
# NOTE: Some of you may have computer issues with the full dataset. In this case, feel free to use [this 10% dataset version of Iowa liquor sales](https://drive.google.com/file/d/0Bx2SHQGVqWaseDB4QU9ZSVFDY2M/view?usp=sharing). You may want to use it anyway to test and prototype your code since it will be faster, before running it on the full dataset.

# %%
file1 = '/Users/tyronewilliams/Desktop/DSI-SF-4-bosydomo/datasets/iowa_liquor/Iowa_Liquor_sales_sample_10pct.csv'

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ### 7.1 Do an initial overview of the data
#
# ---
#
# At the very least describe the columns/variables and the datatypes.

# %%
iowa = pd.read_csv(file1)
iowa.head()
# Out:
#          Date  Store Number         City Zip Code  County Number      County  \
# 0  11/04/2015          3717       SUMNER    50674            9.0      Bremer
# 1  03/02/2016          2614    DAVENPORT    52807           82.0       Scott
# 2  02/11/2016          2106  CEDAR FALLS    50613            7.0  Black Hawk
# 3  02/03/2016          2501         AMES    50010           85.0       Story
# 4  08/18/2015          3654      BELMOND    50421           99.0      Wright
#
#     Category              Category Name  Vendor Number  Item Number  \
# 0  1051100.0           APRICOT BRANDIES             55        54436
# 1  1011100.0           BLENDED WHISKIES            395        27605
# 2  1011200.0  STRAIGHT BOURBON WHISKIES             65        19067
# 3  1071100.0         AMERICAN COCKTAILS            395        59154
# 4  1031080.0             VODKA 80 PROOF            297        35918
#
#             Item Description  Bottle Volume (ml) State Bottle Cost  \
# 0  Mr. Boston Apricot Brandy                 750             $4.50
# 1                    Tin Cup                 750            $13.75
# 2                   Jim Beam                1000            $12.59
# 3    1800 Ultimate Margarita                1750             $9.50
# 4         Five O'clock Vodka                1750             $7.20
#
#   State Bottle Retail  Bottles Sold Sale (Dollars)  Volume Sold (Liters)  \
# 0               $6.75            12         $81.00                   9.0
# 1              $20.63             2         $41.26                   1.5
# 2              $18.89            24        $453.36                  24.0
# 3              $14.25             6         $85.50                  10.5
# 4              $10.80            12        $129.60                  21.0
#
#    Volume Sold (Gallons)
# 0                   2.38
# 1                   0.40
# 2                   6.34
# 3                   2.77
# 4                   5.55

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 8. Clean the liquor dataset
#
# ---
#
# ### 8.1 Identify columns that you will need to convert and clean. Where and how is the data corrupted?
#
# Don't worry about converting the date column to a pandas/numpy "datetime" datatype, unless you want to (not required for these problems and is a challenging thing to work with in its own right.)

# %%
iowa["State Bottle Cost"] = iowa["State Bottle Cost"].str.replace("$","")
iowa["State Bottle Retail"] = iowa["State Bottle Retail"].str.replace("$","")
iowa["Sale (Dollars)"] =iowa["Sale (Dollars)"].str.replace("$","")
iowa["Volume Sold (Liters)"] = iowa["Volume Sold (Gallons)"]*3.78

# %%
iowa[["Sale (Dollars)", "State Bottle Cost", "State Bottle Retail", "Volume Sold (Liters)","Bottle Volume (ml)", "Bottles Sold"]] = iowa[["Sale (Dollars)", "State Bottle Cost", "State Bottle Retail", "Volume Sold (Liters)","Bottle Volume (ml)", "Bottles Sold"]].apply(pd.to_numeric)

# %%
iowa.dtypes
# Out:
# Date                      object
# Store Number               int64
# City                      object
# Zip Code                  object
# County Number            float64
# County                    object
# Category                 float64
# Category Name             object
# Vendor Number              int64
# Item Number                int64
# Item Description          object
# Bottle Volume (ml)         int64
# State Bottle Cost        float64
# State Bottle Retail      float64
# Bottles Sold               int64
# Sale (Dollars)           float64
# Volume Sold (Liters)     float64
# Volume Sold (Gallons)    float64
# dtype: object

# %% [markdown]
# <img src="http://imgur.com/xDpSobf.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ### 8.2 Perform more extensive cleaning of the dataset
#
# Cleaning of data can mean a lot more than just fixing strings and numbers in columns. There are often logical errors with data, useless or nonsensical categories, redundancy of information, outliers, and many more problems.
#
# This dataset has problems beyond just fixing the types of columns. Though resolving them may not be required for EDA and analysis, if you want experience with "deeper" cleaning of data this is a great dataset to start practicing with.
#
# Keep in mind that some types of "data cleaning" is subjective: it's not always a cut-and-dry conversion of type or removal of null values. Subjectivity when dealing with data is just a fact of life for a data scientist. This isn't a kind of programming where things are just right or wrong.

# %%
def year(x):
    s = x.split("/")
    return s[2]

iowa["Year"] = iowa["Date"].apply(year)
iowa["Year"]
# Out:
# 0         2015
# 1         2016
# 2         2016
# 3         2016
# 4         2015
# 5         2015
# 6         2015
# 7         2015
# 8         2016
# 9         2015
# 10        2015
# 11        2015
# 12        2015
# 13        2016
# 14        2016
# 15        2015
# 16        2016
# 17        2015
# 18        2015
# 19        2015
# 20        2015
# 21        2015
# 22        2015
# 23        2015
# 24        2016
# 25        2015
# 26        2015
# 27        2015
# 28        2015
# 29        2015
#           ...
# 270925    2015
# 270926    2015
# 270927    2015
# 270928    2015
# 270929    2016
# 270930    2015
# 270931    2015
# 270932    2015
# 270933    2015
# 270934    2015
# 270935    2015
# 270936    2015
# 270937    2015
# 270938    2015
# 270939    2015
# 270940    2015
# 270941    2015
# 270942    2015
# 270943    2015
# 270944    2016
# 270945    2015
# 270946    2015
# 270947    2015
# 270948    2015
# 270949    2015
# 270950    2015
# 270951    2015
# 270952    2015
# 270953    2015
# 270954    2015
# Name: Year, dtype: object

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 9. Filter/adjust the store data
#
# ---
#
# Some stores may have opened or closed in 2015. These stores will have incorrect yearly summary statistics since they were not open the full year. We need to filter them out or find another way to deal with the inconsistent numbers of months across stores.
#
# It is up to you how you want to deal with this problem.
#
# 1. Investigate problematic stores.
# 2. Decide on an approach to handle missing data for stores not open for the full 2015 year. Do you impute? Remove the stores? Something else?
# 3. Implement your plan.
# 4. Briefly report on what you did and why.

# %%
#Didnt really find the need to find, or seperate stores that were open/closed. Its irrelevant for the analysis
#that we are doing below
iowa_2015 = iowa[iowa["Year"] =="2015"]
iowa_2016 = iowa[iowa["Year"] =="2016"]

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 10. Examine liquor profits
#
# ---
#
# You are a data scientist in residence at the Iowa State tax board. The Iowa State legislature is considering changes in the liquor tax rates and has assigned you to the project.
#
# ### 10.1 Calculate yearly liquor sales for each store in 2015.

# %%
#Look at the data first 
iowa_2015 = iowa[iowa["Year"] =="2015"]
iowa_2015.groupby(["Store Number", "Year"])["Year", "Sale (Dollars)"].sum().reset_index()
# Out:
#       Store Number  Year  Sale (Dollars)
# 0             2106  2015       146326.22
# 1             2113  2015         9310.22
# 2             2130  2015       111871.43
# 3             2152  2015         7721.08
# 4             2178  2015        24324.18
# 5             2190  2015       121689.06
# 6             2191  2015       125093.49
# 7             2200  2015        22811.55
# 8             2205  2015        24681.39
# 9             2228  2015        17462.07
# 10            2233  2015        29553.34
# 11            2238  2015        11762.56
# 12            2248  2015        67682.06
# 13            2285  2015        76927.11
# 14            2290  2015        56514.43
# 15            2327  2015        10245.14
# 16            2353  2015        54000.55
# 17            2367  2015         5010.83
# 18            2413  2015        90065.02
# 19            2445  2015         7189.48
# 20            2448  2015        17740.70
# 21            2459  2015         7352.33
# 22            2460  2015        33731.76
# 23            2465  2015        25831.80
# 24            2475  2015        10681.07
# 25            2478  2015        19840.65
# 26            2487  2015        28900.96
# 27            2498  2015         2259.67
# 28            2500  2015       149121.63
# 29            2501  2015       144833.66
# ...            ...   ...             ...
# 1342          5180  2015         2239.44
# 1343          5181  2015          963.04
# 1344          5182  2015         2612.94
# 1345          5183  2015          916.80
# 1346          5185  2015         1077.39
# 1347          5186  2015          298.86
# 1348          5187  2015         4239.11
# 1349          5188  2015         1887.73
# 1350          5189  2015          604.20
# 1351          5190  2015         1161.73
# 1352          5191  2015          303.90
# 1353          5192  2015           90.00
# 1354          5193  2015          139.50
# 1355          5196  2015          682.85
# 1356          5198  2015         3985.06
# 1357          5199  2015         2046.22
# 1358          5201  2015          289.78
# 1359          5203  2015          928.49
# 1360          5204  2015          790.44
# 1361          5205  2015           39.02
# 1362          5206  2015          500.90
# 1363          5207  2015         3197.95
# 1364          5212  2015          504.54
# 1365          5213  2015          180.00
# 1366          5215  2015           56.03
# 1367          9001  2015        28208.52
# 1368          9002  2015        37700.52
# 1369          9010  2015         5757.96
# 1370          9013  2015         2217.48
# 1371          9018  2015         6435.00
#
# [1372 rows x 3 columns]

# %%
iowa_2015.head()
# Out:
#          Date  Store Number          City Zip Code  County Number  \
# 0  11/04/2015          3717        SUMNER    50674            9.0
# 4  08/18/2015          3654       BELMOND    50421           99.0
# 5  04/20/2015          2569  CEDAR RAPIDS    52402           57.0
# 6  08/05/2015          2596       OTTUMWA    52501           90.0
# 7  06/25/2015          3456    CLEAR LAKE    50428           17.0
#
#         County   Category            Category Name  Vendor Number  \
# 0       Bremer  1051100.0         APRICOT BRANDIES             55
# 4       Wright  1031080.0           VODKA 80 PROOF            297
# 5         Linn  1041100.0        AMERICAN DRY GINS            205
# 6      Wapello  1051010.0  AMERICAN GRAPE BRANDIES             85
# 7  Cerro Gordo  1012100.0        CANADIAN WHISKIES             65
#
#    Item Number           Item Description  Bottle Volume (ml)  \
# 0        54436  Mr. Boston Apricot Brandy                 750
# 4        35918         Five O'clock Vodka                1750
# 5        31473          New Amsterdam Gin                1750
# 6        52806              Korbel Brandy                 750
# 7        10628       Canadian Club Whisky                1750
#
#    State Bottle Cost  State Bottle Retail  Bottles Sold  Sale (Dollars)  \
# 0               4.50                 6.75            12           81.00
# 4               7.20                10.80            12          129.60
# 5              13.32                19.98             6          119.88
# 6               6.66                 9.99             3           29.97
# 7              15.75                23.63             2           47.26
#
#    Volume Sold (Liters)  Volume Sold (Gallons)  Year
# 0                8.9964                   2.38  2015
# 4               20.9790                   5.55  2015
# 5               10.4706                   2.77  2015
# 6                2.2302                   0.59  2015
# 7                3.4776                   0.92  2015

# %% [markdown]
# ### 10.2 Calculate the profit each store is making in 2015.

# %%
#Total cost column
iowa["Total_Cost"] = iowa["State Bottle Cost"] * iowa["Bottles Sold"]

# %%
#Profit Column
iowa["Profit"] = iowa["Sale (Dollars)"] - iowa["Total_Cost"]
iowa_2015 = iowa[iowa["Year"] =="2015"]

# %%
iowa_2015["Profit"]
# Out:
# 0          27.00
# 4          43.20
# 5          39.96
# 6           9.99
# 7          15.76
# 9           7.62
# 10         78.72
# 11         19.50
# 12          4.46
# 15          9.00
# 17         39.00
# 18         59.04
# 19         29.94
# 20         14.26
# 21         31.44
# 22         42.00
# 23         63.00
# 25        214.80
# 26          3.68
# 27          5.25
# 28         33.00
# 29          2.45
# 30          3.00
# 31         12.08
# 32         43.20
# 33         45.72
# 34          5.38
# 35         13.04
# 36         31.68
# 37         73.56
#            ...
# 270923    135.00
# 270924      7.48
# 270925     12.00
# 270926     93.00
# 270927     55.56
# 270928     43.20
# 270930     11.64
# 270931     31.56
# 270932     29.68
# 270933     13.50
# 270934     10.00
# 270935     22.62
# 270936     63.00
# 270937      9.28
# 270938      7.14
# 270939     14.70
# 270940     24.08
# 270941     21.54
# 270942     33.12
# 270943      3.42
# 270945     21.60
# 270946     19.32
# 270947     15.00
# 270948     12.75
# 270949      6.21
# 270950     40.60
# 270951     11.22
# 270952     45.24
# 270953     78.18
# 270954     11.04
# Name: Profit, dtype: float64

# %% [markdown]
# ### 10.3 Investigate which Iowa counties are making the most profit on liquor per gallon in 2015.

# %%
iowa_profit = iowa_2015.groupby("Store Number")["Volume Sold (Gallons)","Profit"].sum().reset_index()

iowa_profit["Profit/Gallon"] = iowa_profit["Profit"] / iowa_profit["Volume Sold (Gallons)"]
iowa_profit.sort_values(by= "Profit/Gallon", ascending=False)
# Out:
#       Store Number  Volume Sold (Gallons)    Profit  Profit/Gallon
# 1220          5053                   0.20     22.50     112.500000
# 886           4669                  36.39   3143.12      86.373179
# 1367          9001                 168.83   9403.68      55.699106
# 1047          4849                  65.81   3332.80      50.642759
# 1358          5201                   2.28     96.65      42.390351
# 1303          5139                  11.02    440.16      39.941924
# 1366          5215                   0.48     18.68      38.916667
# 1368          9002                 328.17  12574.08      38.315751
# 1204          5036                  83.69   3166.06      37.830804
# 1337          5175                   2.05     74.99      36.580488
# 1241          5074                  28.43   1038.87      36.541330
# 1371          9018                  59.44   2145.00      36.086810
# 977           4766                  13.48    480.95      35.678783
# 1369          9010                  56.17   1920.12      34.184084
# 1184          5014                  52.70   1790.36      33.972676
# 1285          5118                   6.35    204.94      32.274016
# 1179          5009                  42.01   1352.29      32.189717
# 1223          5056                   1.81     58.24      32.176796
# 1151          4979                 333.73  10631.11      31.855422
# 530           4210                  30.74    963.96      31.358491
# 867           4648                 524.31  16140.07      30.783449
# 12            2248                 743.70  22584.51      30.367769
# 1056          4860                 235.41   7085.95      30.100463
# 215           3521                 453.87  13636.49      30.044925
# 1363          5207                  35.69   1067.69      29.915663
# 273           3698                 152.23   4520.79      29.697103
# 1330          5168                  68.97   2019.33      29.278382
# 1295          5131                 189.57   5524.18      29.140581
# 318           3805                 445.74  12795.59      28.706398
# 859           4638                 417.02  11915.13      28.572083
# ...            ...                    ...       ...            ...
# 230           3587                  82.03   1002.84      12.225283
# 181           2958                  49.58    605.29      12.208350
# 1138          4960                 130.37   1590.60      12.200660
# 986           4776                  10.31    125.64      12.186227
# 48            2529                 980.19  11894.92      12.135321
# 845           4623                  45.51    551.70      12.122610
# 592           4313                 253.22   3062.11      12.092686
# 397           3972                 107.82   1302.65      12.081710
# 433           4059                   2.91     35.15      12.079038
# 537           4231                 337.53   4072.39      12.065268
# 292           3738                 353.51   4243.80      12.004752
# 598           4321                 269.46   3230.47      11.988681
# 869           4651                 105.64   1262.93      11.955036
# 813           4584                  94.21   1121.93      11.908821
# 391           3959                 261.43   3078.98      11.777455
# 476           4140                 516.02   6069.33      11.761812
# 876           4658                  41.24    480.88      11.660524
# 551           4253                 832.37   9696.00      11.648666
# 535           4229                 960.90  11025.14      11.473764
# 1222          5055                  30.12    345.54      11.472112
# 161           2839                  78.07    888.94      11.386448
# 307           3774                 455.57   5155.57      11.316746
# 763           4527                  43.59    492.00      11.286992
# 1094          4905                  86.05    971.09      11.285183
# 998           4789                  54.70    610.02      11.152102
# 477           4141                 280.35   3101.99      11.064705
# 521           4196                 549.49   6016.30      10.948880
# 1194          5026                  42.72    434.08      10.161049
# 875           4657                  52.72    528.54      10.025417
# 1133          4954                  19.19    190.44       9.923919
#
# [1372 rows x 4 columns]

# %% [markdown]
# ### 10.4 Create a broader category for liquor type.
#
# Liquor types are pretty granular in this dataset. Create a column that categorizes these types into a smaller amount of categories. The categories you decide on are up to you.

# %%
liqour_list = iowa["Item Description"].unique().tolist()

def liqour_type(x):
    liqours = ["vodka","gin", "whiskey", "bourbon", "brandy","rum","tequila", "liqueur"]
    s = x.lower()
    if liqours[0] in s:
        return liqours[0]
    elif liqours[1] in s :
        return liqours[1]
    elif liqours[2] in s:
        return liqours[2]
    elif liqours[3] in s:
        return liqours[3]
    elif liqours[4] in s:
        return liqours[4]
    elif liqours[5] in s:
        return liqours[5]
    elif liqours[6] in s:
        return liqours[6]
    elif liqours[7] in s:
        return liqours[7]
    else:
        return "other"
    
    
d = "Some good vodka"

liqour_type(d)
iowa["Liqour Type"] = iowa["Item Description"].apply(liqour_type)

# %% [markdown]
# ### 10.5 Do relationships exist between the broader liquor type and profit?

# %%
#Getting profit Per Litre 

iowa_profit_perL = iowa.groupby(["Liqour Type"])["Liqour Type", "Profit", "Volume Sold (Liters)"].sum()
iowa_profit_perL["Profit Per L"] = iowa_profit_perL["Profit"]/iowa_profit_perL["Volume Sold (Liters)"]
iowa_profit_perL.sort_values(by = "Profit Per L", ascending = False)
# Out:
#                    Profit  Volume Sold (Liters)  Profit Per L
# Liqour Type
# liqueur      3.932099e+05          5.385876e+04      7.300761
# bourbon      1.627911e+05          2.652619e+04      6.136995
# tequila      4.993696e+05          8.477565e+04      5.890484
# other        5.513738e+06          1.009438e+06      5.462184
# gin          5.544213e+05          1.062206e+05      5.219528
# rum          1.264467e+06          2.711612e+05      4.663155
# whiskey      6.779133e+05          1.530548e+05      4.429218
# brandy       1.808576e+05          4.537176e+04      3.986127
# vodka        2.430699e+06          6.798692e+05      3.575244

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 11. Proposing a new liquor tax
#
# ---
#
# ### The tax board wants to design a tax or taxes that affect larger stores more than smaller "mom and pop" stores.
#
# Based on your investigations into the data, come up with a way you could design a tax that achieves this goal **without explicitly taxing stores based on size or county critera.** The liqour board does not want to obviously punish larger stores or speific counties for fear of backlash, but is willing to tax hard alcohol more than beer, for example.
#
# Feel free to do more EDA if it helps.
#
# Your report should describe whether such a tax is possible or not, and the specifics of what the tax will target/do.

# %%
#Finding the total amount of liqour sold by Store Number
iowa.groupby(["Store Number"])["Store Number","Volume Sold (Liters)"].sum()

#Impose a progressive tax where stores who sell over certain amounts are taxed at higher amounts. For example:
# Stores who sell < 1000L, tax = 0.0%
# Stores who sell < 2500L but > 1000L, tax = 1.0%
# Stores who sell < 5000L but > 2500L, tax = 2.0%
# Stores who sell < 7500L but > 5000L, tax = 3.0%
# Stores who sell < 10000L but > 7500L, tax = 4.0%
# Stores who sell > 10000L , tax = 5.0%

#Easy to implement, since the government can track the amount of liqour sold to each stores. 
#Larger stores obviously sell more and therby are taxed at a higher amount
# Out:
#               Store Number  Volume Sold (Liters)
# Store Number
# 2106               1377324            11834.6130
# 2113                388792              835.4934
# 2130               1084170             8436.8844
# 2152                367992              772.2162
# 2178                642510             2434.6602
# 2190               3560940             7834.9194
# 2191               1619149            10966.2336
# 2200               1067000             2132.9028
# 2205                635040             1554.7518
# 2228                681768             1574.7102
# 2233                647570             2954.2590
# 2238                158898              903.5334
# 2248               1258880             3373.2342
# 2285                818030             4527.6462
# 2290               2383890             4488.3342
# 2327                544518              978.7554
# 2353                974142             4950.5904
# 2367                106515              346.0212
# 2413               1462278             7861.3038
# 2445                489000              691.4376
# 2448               1236240             1656.5094
# 2459                327047              747.5328
# 2460                976620             3388.5054
# 2465               1136365             2059.4574
# 2475                262350             1515.1752
# 2478                265146             1261.5750
# 2487               1017183             2544.2046
# 2498                189848              293.8572
# 2500               3802500            12188.4966
# 2501               3884053            12036.2760
# ...                    ...                   ...
# 5211                 99009              101.2662
# 5212                145936               79.1532
# 5213                 67769               55.5660
# 5214                 62568               67.2084
# 5215                292040              129.8808
# 5216                 15648               15.7248
# 5217                 31302               26.9514
# 5218                 10436                1.5120
# 5220                318420              112.8330
# 5222                172326              398.8656
# 5223                 15669               10.1304
# 5224                104480              115.7436
# 5225                 73150               54.3942
# 5226                 67938               91.5894
# 5227                141129              100.8882
# 5229                 26145               19.0890
# 5230                339950              191.0034
# 5232                 20928               14.5908
# 5233                 20932               17.1612
# 5234                 15702               23.9652
# 5236                256564              310.6782
# 5237                 31422               47.8170
# 5240                 36680               29.7108
# 5247                 36729               20.7144
# 9001                216024              656.1702
# 9002                441098             1289.9628
# 9010                153170              221.3190
# 9013                 54078              200.7558
# 9018                  9018              224.6832
# 9023                  9023               17.9928
#
# [1400 rows x 2 columns]

# %% [markdown]
# <img src="http://imgur.com/GCAf1UX.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 12. Time-related effects
#
# ---
#
# You could imagine that liquor sales might be affected by a variety of effects related to time. Do people buy more beer in the summer? Do liquor sales skyrocket in december? Do people buy less liquor on Tuesdays?
#
# You have the date of sales in your dataset, which you can use to pull out time components.
#
# 1. Come up with 2 different hypotheses about how liquor sales may vary with time-related variables.
# 2. Create a visualization exploring each hypothesis.
# 3. Write brief concluding remarks on what you observed.

# %%
#Investigate whether months affects liqour sales,
#Investigate whether liqour types are affected by changes in months 

def get_month(x):
    s= x.split("/")
    return s[0]

def get_day(x):
    s= x.split("/")
    return s[1]

iowa["Month"]=  iowa["Date"].apply(get_month)
iowa["Day"]= iowa["Date"].apply(get_day)

# %%
#Mean Volume sold by month
iowa.groupby(["Month"])["Liqour Type", "Volume Sold (Liters)"].mean().reset_index()
# Out:
#    Month  Volume Sold (Liters)
# 0     01              8.164117
# 1     02              9.122301
# 2     03              8.493954
# 3     04              9.071861
# 4     05              9.552844
# 5     06              9.444608
# 6     07              8.415664
# 7     08              8.544918
# 8     09              9.015896
# 9     10             11.068928
# 10    11              9.317818
# 11    12              8.584518

# %%
#Mean Volume sold by year
iowa.groupby(["Year"])["Liqour Type", "Volume Sold (Liters)"].mean().reset_index()
# Out:
#    Year  Volume Sold (Liters)
# 0  2015              9.075025
# 1  2016              8.527918

# %%
iowa_volume = iowa.groupby(["Month", "Liqour Type"])["Month", "Liqour Type","Volume Sold (Liters)"].sum()
iowa_volume=iowa_volume.reset_index()

# %%
iowa_volume
# Out:
#     Month Liqour Type  Volume Sold (Liters)
# 0      01     bourbon             2645.5086
# 1      01      brandy             5453.2170
# 2      01         gin            11367.2916
# 3      01     liqueur             6368.5062
# 4      01       other           101113.7148
# 5      01         rum            32404.8816
# 6      01     tequila             7268.0706
# 7      01       vodka            77702.9274
# 8      01     whiskey            15800.9670
# 9      02     bourbon             3047.6250
# 10     02      brandy             5220.2556
# 11     02         gin            11474.4168
# 12     02     liqueur             6408.1962
# 13     02       other           139916.5488
# 14     02         rum            31176.0414
# 15     02     tequila            10160.5266
# 16     02       vodka            73742.6214
# 17     02     whiskey            19862.3502
# 18     03     bourbon             3406.0446
# 19     03      brandy             6312.4488
# 20     03         gin            13703.4450
# 21     03     liqueur             7641.7236
# 22     03       other           130377.9456
# 23     03         rum            34120.7748
# 24     03     tequila            11145.8970
# 25     03       vodka            90556.6284
# 26     03     whiskey            19500.1128
# 27     04     bourbon             1922.8104
# 28     04      brandy             2744.2800
# 29     04         gin             6160.7196
# ..    ...         ...                   ...
# 78     09     tequila             5303.4156
# 79     09       vodka            52733.7594
# 80     09     whiskey            11510.2134
# 81     10     bourbon             1914.2676
# 82     10      brandy             3082.0608
# 83     10         gin             7875.2520
# 84     10     liqueur             3708.4446
# 85     10       other            92056.4946
# 86     10         rum            22719.1986
# 87     10     tequila             5495.0238
# 88     10       vodka            44606.1924
# 89     10     whiskey            11253.0978
# 90     11     bourbon             2046.3030
# 91     11      brandy             3596.3298
# 92     11         gin             7389.8244
# 93     11     liqueur             3899.7504
# 94     11       other            65473.3044
# 95     11         rum            18545.2092
# 96     11     tequila             4566.2778
# 97     11       vodka            46208.0808
# 98     11     whiskey            13694.1462
# 99     12     bourbon             2409.1452
# 100    12      brandy             4790.7342
# 101    12         gin            11562.8310
# 102    12     liqueur             5154.4836
# 103    12       other            81946.2798
# 104    12         rum            22790.2626
# 105    12     tequila             6104.0196
# 106    12       vodka            51360.4854
# 107    12     whiskey            12424.4820
#
# [108 rows x 3 columns]

# %%
g = sns.factorplot(x= "Month", y="Volume Sold (Liters)",hue="Liqour Type",
                   data= iowa_volume, size=10, kind="bar", palette="muted" )

#Tends to be lower alcohol consumption in summer months as compared to winter months

# %%
liqour_list
# Out:
# ['Mr. Boston Apricot Brandy',
#  'Tin Cup',
#  'Jim Beam',
#  '1800 Ultimate Margarita',
#  "Five O'clock Vodka",
#  'New Amsterdam Gin',
#  'Korbel Brandy',
#  'Canadian Club Whisky',
#  'Absolut Swedish Vodka 80 Prf',
#  'Dekuyper Hot Damn!',
#  'Knob Creek Single Barrel Reserve',
#  "Chi-Chi's Margarita W/tequila",
#  'Windsor Canadian Pet',
#  'Kinky Liqueur',
#  'Uv Red (cherry) Vodka',
#  'Uv Cake Vodka',
#  'Juarez Gold Dss',
#  'Lord Calvert Canadian Whisky',
#  '44 North Huckleberry',
#  'Black Velvet Traveler',
#  'Seagrams 7 Crown Bl Whiskey',
#  'Jose Cuervo Especial Reposado Tequila',
#  "Five O'clock PET Vodka",
#  'Jack Daniels Old #7 Black Lbl',
#  'Crown Royal Canadian Whisky Mini',
#  'Hawkeye Blend Whiskey',
#  'UV Vodka PET',
#  'Piehole Apple Pie Mini',
#  'Paramount Gin',
#  'Dekuyper 03',
#  'Dekuyper Sour Apple',
#  'Arrow Wild Cherry Flav Brandy',
#  'Jagermeister Liqueur',
#  'Bartenders Hot Sex',
#  'Tanqueray Gin',
#  'Viniq Ruby',
#  'Wild Turkey 101',
#  'Dekuyper Watermelon Pucker',
#  'Paramount Blackberry Brandy',
#  'New Amsterdam Vodka',
#  'Oban Single Malt Scotch',
#  'Bacardi Superior Rum',
#  'Margaritaville Skinny Island Punch',
#  'Captain Morgan Spiced Rum',
#  'Crown Royal Canadian Whisky',
#  'Grey Goose Vodka',
#  'Rumchata',
#  'J & B Rare Scotch',
#  'Smirnoff Vodka 100 Prf',
#  "Chi-Chi's Orange Cream",
#  'Canadian Ltd Whisky',
#  'Jesse James Bourbon',
#  'Hawkeye Vodka',
#  'Jack Daniels Old #7 Black Lbl Mini',
#  'Baileys Expresso Creme',
#  'Fireball Cinnamon Whiskey Mini Dispenser',
#  'Sailor Jerry Spiced Navy Rum',
#  'Kinky Gold',
#  'Lady Bligh Spiced Rum',
#  'Woodford Reserve Bourbon',
#  'Viniq',
#  'Skol Vodka Traveler',
#  'Jose Cuervo Especial Reposado Flask',
#  "Bailey's Original Irish Cream",
#  'Three Olives Marilyn Monroe Strawberry',
#  "Maker's Mark",
#  'Jameson',
#  '2 Gingers',
#  'Five Star',
#  'Black Velvet Toasted Caramel',
#  'Fris Danish Vodka',
#  'Paramount Gold Rum',
#  'Seagrams Seven Crown Dark Honey',
#  'Bacardi Mango Fusion',
#  'Absolut Cherrykran',
#  'Southern Comfort',
#  'Jose Cuervo Authentic Lime Margarita',
#  'Smirnoff Vodka 80 Prf Pet',
#  "Hendrick's Gin",
#  'Courvoisier Vs Cognac',
#  'Canadian Mist',
#  'Drambuie Liqueur',
#  'Rain Cucumber Vodka',
#  'Jameson Black Barrel',
#  'Jim Beam Maple Mini',
#  'Dekuyper Blackberry Brandy',
#  'Dewars White Label Scotch',
#  'Arrow Spearmint Schnapps',
#  'Black Velvet Reserve',
#  "Grant's Blended Scotch",
#  'Captain Morgan 100 Proof Spiced Rum',
#  'Trader Vics Private Selection Spiced Rum',
#  'Black Velvet',
#  'Captain Morgan Original Spiced',
#  'Bacardi Limon',
#  'Canadian Mist Whisky',
#  "Lauder's",
#  'E & J Vs',
#  'Fireball Cinnamon Whiskey',
#  'Red Stag By Jim Beam',
#  'Smirnoff Vodka 80 Prf',
#  'Popov Vodka 80 Prf',
#  'Evan Williams Cherry Reserve',
#  'Admiral Nelson Spiced Rum',
#  'American Born Moonshine Original',
#  '1800 Silver Tequila',
#  'Paramount Apricot Flavored Brandy',
#  'Arrow Raspberry Schnapps',
#  'Paul Masson Grande Amber Brandy',
#  'Smirnoff Raspberry',
#  'Barton Rum Light',
#  'Peligroso Cinnamon',
#  'Tullamore Dew Irish Whisky',
#  'Skyy Vodka',
#  'Olmeca Altos Plata Mini',
#  'Dekuyper Triple Sec',
#  'Phillips Vodka',
#  'Paramount Amaretto',
#  'Svedka',
#  'Midnight Moon Raspberry',
#  'Bombay Sapphire Gin',
#  'Skol Vodka',
#  'Seagrams Extra Dry Gin',
#  "Burnett's Vodka 80 Prf",
#  'Jose Cuervo Authentic Strawberry Margarita',
#  "Dr. Mcgillicuddy's Cherry Mini",
#  'Jose Cuervo Light White Peach Margarita',
#  'Smirnoff Sorbet Light Mango Passion Fruit',
#  'Seagrams Extra Dry Gin Mini',
#  'Calvert Extra Bl Whiskey',
#  'Kessler Blend Whiskey Mini',
#  'Svedka Vodka',
#  'Three Olives Elvis Coconut Water',
#  'Paramount Cherry Flavored Brandy',
#  'Old Crow',
#  'Hawkeye Vodka 80 Prf Mini',
#  'Plymouth Gin',
#  'UV Cake Vodka',
#  'Smirnoff Sours Berry Lemon',
#  'Crown Royal Regal Apple Mini',
#  'Captain Morgan Spiced Rum Mini',
#  "Chi-Chi's Gold Margarita",
#  'Burnetts Raspberry Vodka',
#  'Corralejo Reposado Tequila',
#  'Jack Daniels Old #7 Black Lbl Square',
#  'Jose Cuervo Golden Margarita',
#  'Kessler Blend Whiskey',
#  'Wisconsin Club Vodka',
#  'Seagrams V.o. Bl Canadian Whisky Pet',
#  "Burnett's Strawberry Banana",
#  "Gordon's Gin London Dry - Pet",
#  'Cedar Ridge Malted Rye',
#  'Dekuyper Peachtree',
#  'Paramount Peppermint Schnapps',
#  'Mccormick Vodka Pet',
#  'Kraken Black Spiced Rum',
#  'Canadian Reserve Whisky',
#  "Five O'clock Gin",
#  'Canadian Club Small Batch Classic',
#  'Johnnie Walker Red Label Scotch',
#  'Titos Vodka',
#  "Ryan's Cream Liqueur",
#  'Johnnie Walker Blue',
#  'Patron Silver Tequila',
#  'Cedar Ridge Apple Brandy',
#  'Admiral Nelson Spiced Rum Traveler',
#  'Paramount Triple Sec',
#  'Ciroc Luxury Vodka',
#  'E & J Vs Brandy',
#  'Uv Blue (raspberry) Vodka',
#  'Rumchata Mini',
#  'Paramount Strawberry Schnapps',
#  'Captain Morgan Cannon Blast Mini',
#  "Dr. Mcgillicuddy's Cherry Schnapps",
#  'Captain Morgan Spiced Barrel',
#  'Malibu Coconut Rum',
#  'Effen Vodka',
#  'E.H. Taylor Jr. Small Batch',
#  'Crown Royal Regal Apple',
#  'Nikolai Vodka',
#  'Uv Grape Vodka',
#  'Sobieski Vodka',
#  'Southern Comfort Caramel',
#  'Absolut Swedish Vodka 80 Prf Mini',
#  'Gentleman Jack',
#  'Everclear Alcohol',
#  'Pinnacle Coconut',
#  'Caravella Limoncello',
#  "Carolan's Irish Cream Liqueur",
#  'Deep Eddy Lemon Mini',
#  'Tuaca Perfect Chill',
#  'Cruzan Mango Rum',
#  'Canadian Mist Whiskey Pet',
#  'Barton Vodka',
#  'Elijah Craig',
#  'Bushmills Irish Honey',
#  'Glenlivet 12 Yr Malt Scotch',
#  "Maker's Mark Cask Strength",
#  'Ten High',
#  'Bird Dog Blackberry Whiskey',
#  'Zaya Guatemalan Rum',
#  'Seagrams Vodka',
#  'E & J Vsop Superior Reserve',
#  'Blue Chair Bay White',
#  'Titos Handmade Vodka',
#  'Tortilla Gold Dss',
#  'Avion Silver',
#  'Kamora Coffee Liqueur',
#  'Beefeater Gin',
#  'Remy Martin Vsop (flask)',
#  'Pinnacle Mimosa Mini',
#  'Christian Bros Brandy',
#  'Smirnoff Vodka 80 Prf Mini',
#  'Tequila Rose Liqueur',
#  'Mr. Boston Blackberry Brandy',
#  'Phillips Gin',
#  'Laphroaig 10 Yr Single Malt Scotch',
#  'Smirnoff Strawberry',
#  "Myers's Rum Original Dark",
#  'Seagrams V.o. Bl Canadian Whisky',
#  'New Amsterdam Peach',
#  'Pendleton 1910',
#  'Scoresby Rare Scotch',
#  'Ricura Mini',
#  'Southern Comfort Mini',
#  "Dr. Mcgillicuddy's Mentholmint",
#  'Cruzan Coconut Rum',
#  "Jack Daniel's Tennessee Honey",
#  'Captain Morgan Long Island Iced Tea',
#  'Kahlua Coffee Liqueur',
#  'Christian Bros Brandy Traveler',
#  'La Prima Tequila/gold',
#  'Rumple Minze Peppermint Schnapps Liqueur',
#  'Malibu Pineapple Rum',
#  'UV Salty Watermelon Mini',
#  'Dekuyper Rootbeer',
#  'Evan Williams Vintage',
#  'New Amsterdam Mango',
#  'Tomatin Single Malt',
#  'Bacardi Superior Rum Mini',
#  'Grand Marnier Cordon Rouge',
#  'Crown Royal Xr Canadian Whiskey',
#  'Phillips Blackberry Flav Brandy',
#  'Crystal Head w/Shaker',
#  'Stolichnaya Russian Vodka 80 Prf',
#  "Fleischmann's Gin",
#  'Ciroc Peach',
#  'Paramount White Rum',
#  'Evan Williams Green Label',
#  'Barton Vodka Pet',
#  'Remy Martin V',
#  'Hornitos Plata',
#  'Tippy Cow Vanilla Soft Serve',
#  "Beam's 8 Star Bl Whiskey",
#  "Bailey's Chocolate Cherry",
#  'Olmeca Altos Plata',
#  'Tanqueray No. Ten',
#  'Juarez Triple Sec',
#  'Hawkeye Light Rum',
#  'Bacardi Arctic Grape Liqueur',
#  'Chivas Regal 12 Yr',
#  'Grangala Triple Orange Liqueur',
#  'Red Stag Hardcore Cider Mini',
#  'Five Star Pet',
#  'Patron Tequila Silver',
#  'Cazadores Reposado',
#  'Templeton Rye',
#  'Cruzan Raspberry Rum',
#  'Bird Dog Apple Flavored Whiskey',
#  'Mccormick Blend Whiskey',
#  'Smirnoff Whipped Cream',
#  "Seagram's Peach Flavored Vodka",
#  'Outerspace',
#  'Malibu Coconut Rum Mini',
#  'Crystal Head Vodka',
#  'Clearheart Gin',
#  'Desert Island Long Island Ice Tea Cocktail',
#  'Captain Morgan Coconut Mini',
#  'Dekuyper Strawberry Pucker',
#  'Dekuyper Blustery Peppermint Burst Schnapps',
#  'Hennessy Vs Cognac',
#  'Citronge',
#  'Weller Special Reserve Bourbon 7yr HA',
#  'Juarez Tequila Silver',
#  'Howdys Apple Pie',
#  'Jack Daniels Old #7 Black Lbl Flat',
#  'Pendleton Canadian Whisky',
#  'Juarez Tequila Gold',
#  'Wild Turkey 81',
#  'Teeling Small Batch Irish Whiskey',
#  "Burnett's Tropical Punch",
#  'Piehole Pecan Pie Mini',
#  'Shellback Silver',
#  'Calico Jack Spiced',
#  'Crown Royal',
#  'Cabo Wabo Reposado',
#  'Sauza 901 Silver',
#  'Johnnie Walker Red',
#  'Evan Williams Yr Str Bourbon',
#  'Dekuyper Signature Blue Curacao',
#  'Dekuyper Luscious Peachtree Schnapps',
#  'Captain Morgan White',
#  'El Jimador Anejo Tequila',
#  "Jack Daniel's Tennessee Honey Mini",
#  'Cruzan Black Cherry Rum',
#  'Uv Vodka',
#  'Jim Beam Kentucky Fire Mini',
#  'Skyy Infusions Wild Strawberry',
#  'Korski Vodka',
#  'Bacardi Pineapple Fusion',
#  'McCormick Vodka',
#  'Sunny Brook Blend Whiskey',
#  'Svedka Strawberry Lemonade',
#  'Kahlua Frozen Mudslide',
#  'Courvoisier Vsop Cognac',
#  'Familia Camarena Reposado',
#  'Hennessy VS',
#  'Hawkeye Gin',
#  'Smirnoff Kissed Caramel',
#  'Arrow Peppermint Schnapps Mini',
#  'Pinnacle Vodka',
#  'Ciroc Apple',
#  'Jim Beam Rye',
#  'Bacardi Oakheart',
#  'Dekuyper Grape Pucker',
#  'Smirnoff Sours Fruit Punch',
#  'Bacardi 151 Proof Rum',
#  'Canadian Ltd Whisky Convenience Pack',
#  'Jagermeister w/Shot Glasses',
#  "Fulton''s Harvest Pumpkin Liqueur",
#  'Hiram Walker Orange Curacao',
#  'Bacardi 8 Rum',
#  'Cointreau Liqueur',
#  'Remy Martin Vsop Cognac',
#  'Midnight Moon Strawberry',
#  'Ciroc Red Berry',
#  'Glenfiddich 12yr Special Reserve',
#  'Dekuyper Hot Damn! Traveler',
#  'Jose Cuervo Especial Silver',
#  'Evan Williams Str Bourbon',
#  'Arrow Peppermint Schnapps',
#  "Blanton's Bourbon",
#  'Hpnotiq',
#  'Captain Morgan Original Spiced Rum Pet',
#  'Ronrico Silver Label Rum (pr)',
#  'Ancient Age Bourbon',
#  'Malibu Passion Fruit Rum',
#  'Southern Comfort 100 Prf',
#  'Tooters Ala Bama Slama',
#  'Grey Goose Cherry Noir',
#  'Christian Bros Brandy-Round',
#  'Malibu Island Melon',
#  'Dekuyper Sour Apple Pucker',
#  "Jack Daniel's Tennessee Fire Mini",
#  'Uv Cherry Red Vodka Mini',
#  'Jim Beam Honey',
#  'Sauza Blue Silver',
#  'Titos Handmade Mini',
#  'Smirnoff Silver Vodka 90 Prf',
#  'New Amsterdam Pineapple',
#  'George Dickel #12',
#  'Jack Daniels Black Label',
#  'Old Grand-Dad 100 Prf Bond Bourbon 4 Yr',
#  'Yukon Jack Canadian Liqueur',
#  'E & J Xo Brandy',
#  'Thunder 101 Peppermint Schnapps',
#  'Bacardi Party Drinks Bahama Mama',
#  'G & W Bourbon',
#  'Paddy Old Irish Whiskey',
#  'Balvenie Caribbean Cask 14yr',
#  'Uv Pink Lemonade Vodka',
#  'Torada Tequila Gold',
#  'Deep Eddy Sweet Tea',
#  'Ron Barcelo Imperial',
#  'Bacardi Gold Rum',
#  'Bakon Vodka',
#  'Wild Turkey American Honey',
#  'Don Julio 1942',
#  'Jameson Mini',
#  'Ingenioz',
#  'Captain Morgan Black Spiced',
#  'Captain Morgan Tattoo',
#  'St. Germain',
#  "Burnett's Mango Pineapple",
#  'Blackheart Premium Spiced Rum',
#  'Ardbeg Uigeadail',
#  'Windsor Canadian',
#  'Stolichnaya Blueberi',
#  'Herradura Gold Reposado 6pak',
#  'Paramount Gin Traveler',
#  'Jose Cuervo Tradicional Reposado Tequila',
#  'Smirnoff Pomegranate',
#  'Wild Turkey 101 Round',
#  'Ezra Brooks 50 Mo Ky Sour Mash Bourbon',
#  'Svedka Raspberry Vodka',
#  'Jagermeister Liqueur Mini',
#  'Mccormick Vodka',
#  'Montezuma Triple Sec',
#  'Bombay Dry Gin',
#  "Fleischmann's Royal Vodka",
#  'Black Velvet Cinnamon Rush',
#  "Gordon's Gin London Dry",
#  'Tequila Rose Liqueur Mini',
#  'Malibu Black',
#  'Bacardi Dragon Berry',
#  'Montezuma Gold Tequila',
#  'Dalwhinnie 15 Yr Single Malt Scotch',
#  'Margaritaville Gold Tequila',
#  "Uncle Bob's Root Beer",
#  'Four Roses Yellow Label',
#  'Red Stag Black Cherry',
#  'Disaronno Amaretto',
#  'Captain Morgan Silver Spiced Rum',
#  'Rich & Rare Reserve',
#  "Serpent's Bite Apple Cider Flavored Whisky Mini",
#  "Arrow Mcdale's Butterscotch Schnapps",
#  'Captain Morgan Lime Bite',
#  'Jagermeister Spice',
#  'Bulleit Bourbon',
#  'El Mayor Reposado',
#  'Templeton Rye w/Flask',
#  'Arrow Anisette',
#  'Cedar Ridge Bourbon',
#  "Gilbey's Gin London Dry",
#  'Arrow Creme de Almond',
#  'Talisker Storm',
#  'Smirnoff Lime',
#  'Kinky Liqueur Mini',
#  'Campari Italian Aperitivo',
#  "Bailey's Salted Caramel",
#  'Smirnoff Vodka Traveller',
#  'Don Julio Blanco Tequila',
#  'Ketel One Imported Vodka',
#  "Dr. Mcgillicuddy's Apple Pie Schnapps",
#  'Midnight Moon Peach Moonshine',
#  "Jim Beam Devil's Cut",
#  'Macallan 18yr Single Malt Scotch',
#  'Skinnygirl Margarita',
#  'Arrow Apricot Flav Brandy',
#  'Slow and Low',
#  'Pinnacle Whipped',
#  'Phillips Root Beer Schnapps',
#  'Smirnoff Root Beer Float',
#  'Midnight Moon Apple Pie',
#  "Jack Daniel's Tennessee Fire",
#  'Rumple Minze Peppermint Mini',
#  'UV Ruby Red Grapefruit',
#  'Evan Williams Honey',
#  'E & J Peach',
#  'Tanqueray Sterling Vodka',
#  'Boodles British Gin London Dry',
#  'New Amsterdam Red Berry',
#  'Captain Morgan Parrot Bay Coconut',
#  'Jim Beam Apple',
#  'Jim Beam Kentucky Fire',
#  'El Jimador Silver Tequila',
#  'Crown Royal Black',
#  'Benchmark Old No. 8',
#  'Smirnoff Sours Green Apple',
#  'Hpnotiq Mini',
#  'Captain Morgan Pineapple',
#  'Kinky Blue',
#  'Buchanan Special Reserve 18YR',
#  'E & J Vs Brandy Round',
#  "Serpent's Bite Apple Cider Flavored Whisky",
#  'Grey Goose VX',
#  'Paramount White Rum Traveler',
#  'St. Remy Vsop Napoleon Brandy',
#  'Absolut Vanilia',
#  'Captain Morgan Spiced Rum Pet',
#  'Bacardi Torched Cherry',
#  "Gordon's Vodka 80 Prf - Pet",
#  'Fireball Cinnamon Whisky',
#  'Paul Masson Vs Brandy Mini',
#  'Galliano Liqueur',
#  'Jose Cuervo Especial Reposado Tequila Mini',
#  'Outerspace Vodka',
#  "Serpent's Bite Apple Cider",
#  "Dekuyper Ragin' Root Beer Schnapps",
#  'Fireball Cinnamon',
#  'Paramount Gold Rum Traveler',
#  'Skinnygirl White Peach Margarita',
#  'Seagrams Peach Twisted Gin',
#  'Captain Morgan Parrot Bay Strawberry',
#  'Red Stag Black Cherry Mini',
#  'Smirnoff Peach',
#  "Griff's Cowboy Whiskey",
#  'Red Boot Spiced Whiskey',
#  'Korbel Brandy Pet',
#  'Malibu Red',
#  'Seagrams Extra Smooth',
#  'Monte Alban Mezcal',
#  'Seagrams Seven Crown Orchard Apple',
#  'Admiral Nelson Coconut Rum',
#  'Romana Sambuca Italian Liquore',
#  'Firefly Sweet Tea Vodka',
#  'Pinnacle Red Berry',
#  "Tim Smith's Climax Moonshine",
#  "Mcmaster's Canadian",
#  'Absolut Citron (lemon Vodka)',
#  'Admiral Nelson Cherry Spiced Rum',
#  'Tooters Apple-Tini Mini',
#  'Dewars 12yr',
#  'Jose Cuervo Especial Reposado Square',
#  'Mt. Gay Eclipse Rum',
#  'Knob Creek Smoked Maple',
#  'Smirnoff Orange',
#  'Jose Cuervo Authentic Teagarita Margarita 4pk Cans',
#  'Macallan 12 Yr Single Malt Scotch',
#  'Tippy Cow Shamrock Mint',
#  'Canadian Club w/Glass',
#  'Ciroc Pineapple',
#  'Captain Morgan Cannon Blast',
#  'Kinky Blue Mini',
#  'Sauza Blanco Silver',
#  'Dekuyper Buttershots',
#  'Captain Morgan 1671',
#  'Jose Cuervo Authentic Watermelon Margarita',
#  'Appleton Signature Blend',
#  "Juggs Cherry Cha-Cha's",
#  'Old Forester Signature 100prf Bourbon',
#  'New Amsterdam Orange',
#  "Dr. Mcgillicuddy's Vanilla",
#  "Travis Hasse's Cow Pie",
#  'E.H. Taylor Jr. Straight Rye Why. HA',
#  'Bacardi O',
#  'Pearl Mini Party Pack',
#  'Paramount Butterscotch Schnapps',
#  'Stoli Strasberri Vodka',
#  'Dekuyper Mixed Berry Medley',
#  'Uv Citruv (citrus) Vodka',
#  'Grand Marnier Raspberry Peach',
#  'Cody Road Rye',
#  'Wild Turkey 101 Mini',
#  'Glenlivet 16yr Nadurra',
#  'McCormick Vodka Mini',
#  'Dekuyper Sour Apple Pucker Traveler',
#  'Duke Bourbon Whiskey',
#  "Travis Hasse's Cherry Pie Liqueur",
#  'Skinnygirl White Cranberry Cosmo',
#  'Fireball Cinnamon Whiskey PET',
#  'Calvert Gin',
#  "Bailey's Original Irish Cream Minis",
#  'Smirnoff Citrus',
#  'Northern Light',
#  'Pearl Grape',
#  "Burnett's Citrus",
#  'Rain Mango',
#  'Absolut Mandrin',
#  'Four Roses Single Barrel',
#  'Calico Jack Spiced Rum',
#  'Barton Gin',
#  'Ketel One',
#  'Chambord Liqueur Royale De France',
#  'Paramount Creme De Menthe/white',
#  'Pearl Vodka PET',
#  'Early Times 36 Mo Ky Str Bourbon Pet',
#  'Chopin Vodka',
#  'Effen Football Sleeve',
#  'Revel Stoke Roasted Pecan',
#  'Cinerator Mini',
#  'Windsor Black Cherry',
#  'Black Velvet Mini',
#  'Patron Reposado Tequila',
#  'Malibu Mango Rum',
#  'Bourbon Supreme Bourbon',
#  'Captain Morgan Parrot Bay Key Lime',
#  'Three Olives Tartz',
#  'Southern Host Whiskey Liqueur',
#  'Fernet Branca Liqueur',
#  'Three Olives Grape Mini',
#  'Jeremiah Weed Sarsaparilla Whiskey',
#  'UV Candy Bar',
#  "Russell's Reserve 10YR",
#  'B&b D.o.m.',
#  'La Collection Race Car',
#  'Arrow Creme de Cacao White',
#  'Southern Comfort PET',
#  'Skyy Infusions Pineapple',
#  'Smirnoff Vanilla',
#  'Glenlivet 18yr',
#  'Midnight Moon Cherry',
#  'Jose Cuervo Coconut Pineapple',
#  'Deep Eddy Ruby Red',
#  'Dekuyper Island Punch Pucker',
#  'Bird Dog Apple Flavored Whiskey Mini',
#  'Tortilla Gold Tequila',
#  'Pearl Cucumber Vodka',
#  'Paramount Vodka',
#  'Paramount Peach Schnapps',
#  'Cinerator',
#  'Caffe Lolita Coffee Liqueur',
#  'Pinnacle Peach w/ Punch Dispenser',
#  "Fleischmann's Royal Vodka 80 Prf",
#  '1800 Peach',
#  'Sauza Gold',
#  'Cabin Still Str Bourbon',
#  'Brown Jug Bourbon Cream',
#  'Uv Blue Raspberry Vodka Mini',
#  'Smirnoff Grape',
#  'Seagrams Extra Dry Gin Pet',
#  'Jose Cuervo Authentic Grapefruit Tangerine Margarita',
#  "Burnett's Cherry Vodka",
#  'Jim Beam Mini',
#  'TGIFridays Strawberry Margarita',
#  'Bacardi 151 Prf',
#  "Maker's 46",
#  'Paramount Creme De Cacao/white',
#  'Cedar Ridge Reserve Bourbon',
#  'Don Julio Anejo Tequila',
#  'Dekuyper Luscious Razzmatazz',
#  'Barton Vodka Mini',
#  'Absolut Pears',
#  'Paramount Creme De Menthe/green',
#  'Three Olives Loopy Flavored Vodka',
#  'George Dickel Rye',
#  "Salvador's Original Margarita PET",
#  'Phillips Lime Flavored Vodka',
#  "Fleischmann's Preferred Bl Whiskey",
#  'Old Crow Traveler',
#  'Mr. Boston Riva Gin',
#  'Absolut Raspberri',
#  'Cutty Sark Scotch',
#  "Chi-Chi's White Russian",
#  'Dekuyper Buttershots Schnapps',
#  'Johnnie Walker Black',
#  "Burnett's Watermelon",
#  'Jim Beam Black',
#  'Russian Standard Original Vodka',
#  'Ron Zacapa 23 Year',
#  'Bacardi Select Rum',
#  'E & J Vsop Superior Reserve Mini',
#  "Buchanan's 12 Yr Deluxe Scotch",
#  'Captain Morgan Private Stock Rum',
#  'Paramount Peach Flavored Brandy',
#  'Knob Creek',
#  'Midnight Moon Original',
#  'McCormick Gin Pet',
#  'Jim Beam Honey Mini',
#  'Di Amore Amaretto',
#  'Smirnoff Iced Cake',
#  'Captain Morgan Grapefruit',
#  'Stock 84 Brandy',
#  'Paul Masson Peach Grande Amber Brandy',
#  'Sugar Island Coconut',
#  'Dekuyper Signature Creme De Banana',
#  'Ricura',
#  'Tippy Cow Chocolate Mini',
#  'Basil Hayden 8YR',
#  'Castillo Silver Rum',
#  'Seagrams 7 Crown Pet Flask',
#  "Ole Smoky Hunch Punch Lightnin'",
#  'Three Olives Vodka',
#  'Hornitos Gold',
#  'Ardbeg Corryvreckan',
#  'Hennessy VSOP Privilege',
#  'Peligroso Reposado',
#  'Canadian Mist Canadian Why Pet',
#  "Chi-Chi's Mexican Mudslide",
#  'McClelland Islay',
#  'UV Sangria',
#  'Firewater Cinnamon Schnapps',
#  'Mcclelland Highland',
#  'Hennessy Black',
#  'Skinnygirl Bare Naked',
#  'Margaritaville Silver Tequila',
#  'UV Candy Bar Mini',
#  "Jim Beam Devil's Cut Mini",
#  'Kinky Gold Mini',
#  'Hennessy Vs Cognac Minis',
#  'Kinky Vodka',
#  'Evan Williams Fire',
#  'Pinnacle Tropical Punch',
#  'Phillips Vodka Ez Pack',
#  'Chila Orchata',
#  'Dimple Pinch(haig & Haig)',
#  'Jose Cuervo Mango Margarita',
#  'Jose Cuervo Authentic Lime Margarita 4pk Cans',
#  'Rich & Rare Apple Mini',
#  'Stolichnaya Premium Vodka 80 Proof (lv)',
#  'Tortilla White Tequila',
#  'Hakushu 12YR HA',
#  'Cazadores Anejo',
#  'Clan Macgregor Scotch',
#  'Maraska Kruskovac',
#  'Arrow Peach Schnapps',
#  '2 Gingers Mini',
#  'Don Q Cristal Rum',
#  'Bacardi Black Razz',
#  'Jose Cuervo Authentic Light Margarita Lime',
#  'Dekuyper Raspberry Pucker',
#  'Swell Vodka',
#  'Tanqueray Rangpur Gin',
#  'Rondiaz Rum Spiced Black Cherry',
#  "Burnett's Blue Raspberry Vodka",
#  'Bushmills Irish Whiskey',
#  'Glenmorangie 10 Yr Single Malt Scotch',
#  'Kapali Coffee Liqueur',
#  'Smirnoff Grape Vodka',
#  'Ciroc Red Berry Mini',
#  'Smirnoff Cherry',
#  'Cold Spell Mint Whiskey',
#  'Midori Melon Liqueur',
#  'Paramount Sloe Gin',
#  '99 Blackberries',
#  'Cedar Ridge Single Malt Whiskey',
#  'Windsor Canadian Supreme Whisky',
#  'Pinnacle Peach',
#  "Two Jay's Grappa",
#  'Jeremiah Weed Sweet Tea Vodka',
#  'La Collection Santa Claus',
#  'Cedar Ridge Pear Brandy',
#  'Disaronno Amaretto Cavalli Mignon 3-50ml Pack',
#  'Bird Dog Peach Flavored Whiskey',
#  'Ketel One Citroen',
#  'Buffalo Trace Bourbon',
#  "Chi-Chi's Skinny Margarita",
#  'UV Whipped',
#  'Bird Dog Maple',
#  'Paul Masson Peach Grande Amber Brandy Mini',
#  'Early Times 36 Mo Ky Str Bourbon',
#  'Smirnoff Watermelon',
#  'Yukon Jack Wicked Hot',
#  'Goldschlager Cinnamon Schnapps',
#  'Phillips Long Island Iced Tea',
#  'Famous Grouse Scotch',
#  'Stone Fence Apple Cider Whiskey',
#  'Stolichnaya Razberi Vodka 75 Proof',
#  'Paramount Creme De Cacao/dark',
#  'Absolut Ruby Red',
#  'Cruzan Blueberry Lemonade',
#  "Fleischmann's Dry Gin",
#  "Laird's Applejack",
#  'Atomic Cinnamon Whiskey',
#  'Tippy Cow Chocolate',
#  '1800 Reposado Tequila',
#  "Russell's Reserve Rye 6YR",
#  'Pearl Peach',
#  'Grey Goose Vodka Mini',
#  'Kessler Blend Whiskey Traveler',
#  'Shady Fruit Real Ruby Red Grapefruit Mini',
#  'Godiva White Chocolate Liqueur',
#  'Cold Spell Mint Mini',
#  'Bacardi Classic Cocktails Mojito',
#  'Lock Stock & Barrel',
#  'Crown Royal Special Reserve',
#  'Hennessy 250 Collector Blend HA',
#  'Phillips White Rum',
#  "Seagram's Red Berry Flavored Vodka",
#  "McCormick's Irish Cream",
#  'Peligroso Silver',
#  'Tortilla Triple Sec',
#  'Sauza Cien Anos Reposado',
#  'La Collection $100 Banknote',
#  'Licor 43',
#  "Lauder's Scotch",
#  'Christian Bros Honey',
#  "Booker's 6YR",
#  'Glenfiddich 15 Yr Solera Reserva',
#  "Pimm's Cup No. 1",
#  'Knob Creek w/Glasses',
#  'Blue Chair Bay Coconut',
#  'Mccormick Blend Whiskey, Pet',
#  'Paramount Peppermint Schnapps Traveler',
#  'Three Olives Chocolate Vodka',
#  'Deep Eddy Cranberry',
#  'Piehole Cherry Pie Mini',
#  'Svedka 100 Proof',
#  'Opulent Vodka',
#  'Canadian Woods Canadian Why',
#  'Woodford Reserve Double Oaked',
#  "Dr. McGillicuddy's Peach",
#  'Calico Jack Cherry',
#  'Holstein',
#  'Courvoisier Vs Coganc',
#  'Evan Williams 1783',
#  'UV Sriracha',
#  'Skyy Infusions Georgia Peach',
#  "Bailey's Vanilla Cinnamon",
#  'Ciroc Coconut',
#  'Captain Morgan Coconut',
#  '99 Cinnamon Mini',
#  'Green Spot',
#  'American Born Moonshine Apple Pie',
#  'Hibiki Harmony HA',
#  '99 Bananas Mini',
#  'Bird Dog Jalapeno Honey',
#  'El Mayor Anejo Tequila',
#  'Jack Daniels Winter Jack',
#  'Firefly Apple Pie Moonshine',
#  'Absolut Apeach',
#  'Ice 101, Peppermint Schnapps',
#  'Frangelico Liqueur',
#  'Yahara Bay Barrell Mellowed Gin',
#  'Bacardi Gold Rum Mini',
#  'Black Velvet Toasted Caramel Mini',
#  'Familia Camarena Silver',
#  'Stolichnaya Cranberi Vodka',
#  "Burnett's Gin London Dry",
#  'Admiral Nelson Spiced Rum Mini',
#  'Absolut Berri Acai',
#  'Uv Green (apple) Vodka',
#  'Midnight Moon Blueberry',
#  'Chila Coffee Liqueur',
#  'Jeremiah Weed Peach Sweet Tea',
#  'El Jimador Reposado Tequila',
#  "Five O'clock",
#  'Uv Ivory (vanilla) Vodka',
#  'Glenlivet 15 Year French Oak',
#  'Paramount Blue Curacao',
#  'Tooters Blu-Dacious Kamikazi Mini',
#  "D'usse VSOP",
#  'Avion Reposado',
#  "Chi-Chi's Long Island Iced Tea",
#  'UV Salty Watermelon',
#  'Smirnoff Blueberry',
#  'American Born Moonshine Dixie',
#  'Ridgemont Reserve 1792',
#  'Rondiaz Rum Spiced',
#  'Captain Morgan Parrot Bay Pineapple',
#  'Dekuyper Cactus Juice',
#  'Skinnygirl Sweet Rita',
#  'Pearl Blueberry Vodka',
#  'Seagrams Lime Twisted Gin',
#  'Rich & Rare Canadian Whisky',
#  'Jim Beam Bonded',
#  'Prairie Organic Cucumber',
#  'Cruzan Velvet Cinn',
#  'Ice Hole Butterscotch Schnapps',
#  'E & J Vs Brandy Square',
#  'Three Olives Cherry Mini',
#  'Patron Xo Cafe',
#  'Dekuyper Sour Apple Pucker Pet',
#  'Pearl Vanilla Bean',
#  'Margaritaville Last Mango Margarita',
#  'Rebel Yell',
#  'New Amsterdam Coconut',
#  'Smirnoff Sorbet Light Pineapple Coconut',
#  'Johnnie Walker Double Black',
#  'Mccormick Vodka PET',
#  'Absolut Peppar',
#  'Di Amore Quattro Orange',
#  'Jack Daniels w/Glass',
#  'UV Sugar Crush',
#  'Jose Cuervo Silver "Rolling Stones"',
#  '99 Bananas',
#  'Godiva Liqueur',
#  'Dekuyper Peachtree Schnapps',
#  "Usher's Green Stripe",
#  'Sminoff Sourced Pineapple Mini',
#  "Chi-Chi's Strawberry Margarita W/tequila",
#  'Hawkeye Blue Raspberry Vodka',
#  'Bacardi Party Drinks Hurricane',
#  'Cruzan Vanilla Rum',
#  'Casamigos Reposado',
#  'Woodford Reserve',
#  'E & J Vs Brandy Mini',
#  'Bulldog Gin',
#  'New Amsterdam Vodka Mini',
#  "Uncle Bob's Root Beer Mini",
#  'Dekuyper Cherry Pucker Schnapps',
#  '99 Peppermint Mini',
#  'Smirnoff Sorbet Light Raspberry Pomegranate',
#  'Three Olives Grape Vodka',
#  'Bacardi Superior PET',
#  'Prairie Organic Gin',
#  'Absolut Nightlife',
#  'Platinum 7x Vodka',
#  'Balvenie 12yr Doublewood Single Malt Scotch',
#  'UV Chocolate Cake',
#  'Patron Tequila Silver Mini',
#  'Mr. Boston Rock & Rye',
#  'Pearl Pomegranate Vodka',
#  'Jeremiah Weed Sweet Tea',
#  'Prairie Fire',
#  'Admiral Nelson Spiced 101',
#  'Popov Vodka 80 Prf Traveler',
#  'Black Velvet Cinnamon Rush Mini',
#  'Bacardi Classic Cocktails Strawberry Daiquiri',
#  'Glenfiddich 18 Yr Ancient Reserve',
#  'Iowish Whiskey',
#  'Hot Stuff',
#  'Effen Black Cherry Vodka',
#  'Chivas Regal w/2 Glasses',
#  'Rumchata Iced Coffee Pack',
#  'Jose Cuervo Authentic Strawberry Lime Margarita 4pk Cans',
#  'Jose Cuervo Cinge Mini',
#  'Smirnoff Green Apple',
#  "Burnett's Limeade Vodka",
#  "Burnett's Grape Vodka",
#  'Cragabus Blended',
#  "Gordon's Vodka 80 Prf",
#  "Dr. McGillicuddy's Apple Pie Mini",
#  "Gosling's Black Seal",
#  "Chi-Chi's Pina Colada W/rum",
#  "Dr. McGillicuddy's Peach Mini",
#  "Dr. Mcgillicuddy's Root Beer Schnapps",
#  'Outerspace Mini',
#  'Dekuyper Grape Pucker Schnapps',
#  'Uv Blue Raspberry Vodka Traveller',
#  'Yukon Jack Perma Frost Schnapps',
#  'Espolon Blanco',
#  'Hirsch Small Batch Bourbon',
#  'Margaritaville Classic Lime Margarita',
#  'Uv Orange Vodka',
#  'Ole Smoky Lemon Drop Moonshine',
#  'Jose Cuervo Pink Lemonade',
#  'Rich & Rare Caramel',
#  'Jagermeister w/Flask',
#  'Southern Comfort Pet',
#  'Evan Williams Black Label Traveler',
#  'Disaronno Amaretto Cavalli Wrap',
#  "St. Brendan's Superior Irish Cream Liqueur",
#  'Montezuma Blue',
#  'Pama Pomegranate Liqueur',
#  'Hornitos Black Barrel',
#  'Red Boot Corn Whiskey',
#  'Cruzan Dark Rum',
#  'Ciroc Amaretto',
#  'Ice Box Mudslide',
#  'Bastille Hand Crafted Whisky',
#  'Jeremiah Weed Spiced Whiskey',
#  'Bacardi Superior Rum Pet',
#  'Smirnoff Sorbet Light Lemon',
#  'Forbidden Secret Pumpkin Spice Liqueur',
#  'Smirnoff Pineapple',
#  'Iowish Cream Liqueur',
#  "Jefferson's Reserve",
#  'Whiskey Liqueur',
#  'Stolichnaya Vanil Vodka 75 Proof',
#  'Jim Beam Traveler',
#  'Dekuyper Michigan Cherry Liqueur',
#  'Ancho Reyes',
#  'Three Olives Cherry Vodka',
#  'After Shock Cinnamon Liqueur',
#  'Dekuyper Cherry Pucker',
#  'Jose Cuervo Light Wild Berry Margarita',
#  'Laphroaig Quarter Cask',
#  'Bacardi Peach Red',
#  'Tippy Cow Orange Cream',
#  'Windsor Canadian Traveler',
#  "Salvador's Strawberry Margarita 200ml-4Pack",
#  'Avion Anejo',
#  'Christian Bros Grand Reserve Vsop',
#  'Dekuyper Hot Damn! 100 Proof',
#  'Romana Black Sambuca',
#  'Forty Creek',
#  'Talisker 10YR',
#  'X Rated Fusion Liqueur',
#  'Dekuyper Buttershots Schnapps Traveler',
#  'Monkey Shoulder',
#  'Bowmore Small Batch',
#  'Bulleit 95 Rye',
#  'Hennessy Vs Cognac 100ml',
#  'Ole Smoky Original Corn Moonshine',
#  "Chi-Chi's Ruby Red Margarita",
#  'Maui Blue Hawaiian Schnapps',
#  'E & J Vs Brandy Travelers',
#  'Absolut Vodka 100 Premium',
#  'Ice Hole Plum Schnapps',
#  'Tullamore Dew',
#  'Four Roses Small Batch',
#  'E & J Apple',
#  'Paramount Melon Liqueur',
#  'Kahlua Coffee Liqueur Mini',
#  'Cruzan Strawberry Rum',
#  'Presidente Grape Brandy (pedro Domecq)',
#  'Christian Brothers Holiday Nog',
#  'Five Star Pirate Sword',
#  'Rittenhouse Rye 100 Proof-HA',
#  'UV Chocolate Cake Mini',
#  'Reyka Vodka',
#  'Three Olives Peach',
#  'Remy Martin 1738 Accord Royal',
#  'Paul Masson Red Berry Grande Amber Brandy',
#  'Glenfiddich 14YR',
#  'Jameson Gold',
#  'Legacy Canadian Whisky',
#  'Captain Morgan Parrot Bay Passion Fruit',
#  'French Kiss Tropical Liqueur Mini',
#  'Absolut Orient Apple',
#  'Uv Blue Raspberry Lemonade Pet',
#  'Piehole Cherry Pie',
#  'Dekuyper Peachtree Schnapps Pet',
#  'Yukon Jack Jacapple',
#  'Deep Eddy Lemon Vodka',
#  'Belvedere Intense Unfiltered',
#  'Margaritaville Skinny Margarita',
#  'Auchentoshan 12YR',
#  '99 Apples',
#  'Glenmorangie 18yr HA',
#  'Kringle Cream',
#  'Stolichnaya Elit Vodka',
#  'Southern Comfort Cherry',
#  "Jim Beam Jacob's Ghost",
#  'Il Tramonto Limoncello',
#  'Bacardi Party Drinks Zombie',
#  'Sweet Revenge',
#  'McCormick Gin',
#  'Arrow Creme De Menthe Green',
#  ...]

# %%
#Results:
# Winter months there tends to be a large increase in total liqour sales as compared to summer months
#However our groupby shows that the average amount of liqour tends to remain constant over the years. 
#Regression would be the next step in finding finding if these finding are statistically significant
