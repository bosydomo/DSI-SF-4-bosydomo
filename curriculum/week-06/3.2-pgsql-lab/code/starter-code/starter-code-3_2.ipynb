# %% [markdown]
# # SQL Lab
#
# In this lab we will learn how to use execute SQL from the ipython notebook and practice some queries on the [Northwind sample database](https://northwinddatabase.codeplex.com/) that we used in Lesson 3.1.
#
# You can access the data with this command:
#
#     psql -h dsi.c20gkj5cvu3l.us-east-1.rds.amazonaws.com -p 5432 -U dsi_student northwind
#     password: gastudents

# %% [markdown]
# First of all let's install the ipython-sql extension. You can find instructions [here](https://github.com/catherinedevlin/ipython-sql).
#
# _Instructor note:  This extension is inconsistent.  There was a point it was stable, but use the %sql extension at your own risk.. (There is really not risk other than it doetsn't work correctly)._

# %%
# !pip install ipython-sql

# %% [markdown]
# Let's see if it works:

# %%
# %load_ext sql

# %%
# %%sql postgresql://dsi_student:gastudents@dsi.c20gkj5cvu3l.us-east-1.rds.amazonaws.com/northwind
#
# select * from orders limit 5;

# %% [markdown]
# Nice!!! We can now go ahead with the lab!

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from sqlalchemy import create_engine
import pandas as pd
engine = create_engine('postgresql://dsi_student:gastudents@dsi.c20gkj5cvu3l.us-east-1.rds.amazonaws.com:5432/northwind')


pd.read_sql("SELECT tablename FROM pg_catalog.pg_tables WHERE schemaname='public'", con=engine)
# Out:
#                tablename
# 0             categories
# 1      full_order_table5
# 2                     fo
# 3             table_join
# 4             full_order
# 5   customercustomerdemo
# 6   customerdemographics
# 7              customers
# 8              employees
# 9    employeeterritories
# 10         order_details
# 11                orders
# 12              products
# 13                region
# 14              shippers
# 15          shippers_tmp
# 16             suppliers
# 17           territories
# 18              usstates
# 19                table1
# 20                movies
# 21               ratings
# 22      categoriesmerged
# 23           order_table
# 24              full_ord
# 25             new_table
# 26      full_order_table
# 27     full_order_table2
# 28     full_order_table3
# 29     full_order_table4
# 30            temp_table
# 31          full_orders_
# 32           fullorders_
# 33          fullorders__
# 34            fullorders
# 35          descriptions
# 36                 price
# 37         descriptions1
# 38              empterid
# 39            google_app
# 40                 final
# 41                final2
# 42                final3
# 43                final4
# 44   credit_card_feature
# 45                price2
# 46         descriptions2
# 47             empterid2
# 48                final5
# 49              my_table
# 50             newregion
# 51          updatdregion
# 52         updatedregion
# 53        updatedregion1

# %% [markdown]
# ## 1: Inspect the database
#
# If we were connected via console, it would be easy to list all tables using `\dt`. We can however access table information performing a query on the `information_schema.tables` table.
#
# ### 1.a: List Tables
#
# 1. write a `SELECT` statement that lists all the tables in the public schema of the `northwind` database, sorted alphabetically

# %%
sql_query="""
SELECT *
FROM pg_catalog.pg_tables
WHERE schemaname = 'public'
ORDER BY "tablename" ASC

"""

df = pd.read_sql(sql_query, con=engine)
df
# Out:
#    schemaname             tablename   tableowner tablespace hasindexes  \
# 0      public            categories          dsi       None       True
# 1      public      categoriesmerged  dsi_student       None       True
# 2      public   credit_card_feature  dsi_student       None      False
# 3      public  customercustomerdemo          dsi       None       True
# 4      public  customerdemographics          dsi       None       True
# 5      public             customers          dsi       None       True
# 6      public          descriptions  dsi_student       None      False
# 7      public         descriptions1  dsi_student       None      False
# 8      public         descriptions2  dsi_student       None      False
# 9      public             employees          dsi       None       True
# 10     public   employeeterritories          dsi       None       True
# 11     public              empterid  dsi_student       None      False
# 12     public             empterid2  dsi_student       None      False
# 13     public                 final  dsi_student       None      False
# 14     public                final2  dsi_student       None      False
# 15     public                final3  dsi_student       None      False
# 16     public                final4  dsi_student       None      False
# 17     public                final5  dsi_student       None      False
# 18     public                    fo  dsi_student       None      False
# 19     public              full_ord  dsi_student       None      False
# 20     public            full_order  dsi_student       None      False
# 21     public      full_order_table  dsi_student       None      False
# 22     public     full_order_table2  dsi_student       None      False
# 23     public     full_order_table3  dsi_student       None      False
# 24     public     full_order_table4  dsi_student       None      False
# 25     public     full_order_table5  dsi_student       None      False
# 26     public          full_orders_  dsi_student       None      False
# 27     public            fullorders  dsi_student       None      False
# 28     public           fullorders_  dsi_student       None      False
# 29     public          fullorders__  dsi_student       None      False
# 30     public            google_app  dsi_student       None      False
# 31     public                movies  dsi_student       None       True
# 32     public              my_table  dsi_student       None      False
# 33     public             new_table  dsi_student       None      False
# 34     public             newregion  dsi_student       None      False
# 35     public         order_details          dsi       None       True
# 36     public           order_table  dsi_student       None      False
# 37     public                orders          dsi       None       True
# 38     public                 price  dsi_student       None      False
# 39     public                price2  dsi_student       None      False
# 40     public              products          dsi       None       True
# 41     public               ratings  dsi_student       None       True
# 42     public                region          dsi       None       True
# 43     public              shippers          dsi       None       True
# 44     public          shippers_tmp          dsi       None       True
# 45     public             suppliers          dsi       None       True
# 46     public                table1  dsi_student       None      False
# 47     public            table_join  dsi_student       None      False
# 48     public            temp_table  dsi_student       None      False
# 49     public           territories          dsi       None       True
# 50     public          updatdregion  dsi_student       None      False
# 51     public         updatedregion  dsi_student       None      False
# 52     public        updatedregion1  dsi_student       None      False
# 53     public              usstates          dsi       None      False
#
#    hasrules hastriggers
# 0     False       False
# 1     False       False
# 2     False       False
# 3     False       False
# 4     False       False
# 5     False       False
# 6     False       False
# 7     False       False
# 8     False       False
# 9     False       False
# 10    False       False
# 11    False       False
# 12    False       False
# 13    False       False
# 14    False       False
# 15    False       False
# 16    False       False
# 17    False       False
# 18    False       False
# 19    False       False
# 20    False       False
# 21    False       False
# 22    False       False
# 23    False       False
# 24    False       False
# 25    False       False
# 26    False       False
# 27    False       False
# 28    False       False
# 29    False       False
# 30    False       False
# 31    False       False
# 32    False       False
# 33    False       False
# 34    False       False
# 35    False       False
# 36    False       False
# 37    False       False
# 38    False       False
# 39    False       False
# 40    False       False
# 41    False       False
# 42    False       False
# 43    False       False
# 44    False       False
# 45    False       False
# 46    False       False
# 47    False       False
# 48    False       False
# 49    False       False
# 50    False       False
# 51    False       False
# 52    False       False
# 53    False       False

# %% [markdown]
# ### 1.b: Print Schemas
#
# The table `INFORMATION_SCHEMA.COLUMNS` contains schema information on each.
#
# Query it to display schemas of all the public tables. In particular we are interested in the column names and data types. Make sure you only include public schemas to avoid cluttering your results with a bunch of postgres related stuff.

# %% [markdown]
# ### 1.c: Table peek
#
# Another way of quickly looking at table information is to query the first few rows. Do this for a couple of tables, for example: `orders`, `products`, `usstates`. Display only the first 3 rows.

# %%
sql_query="""
SELECT *
FROM orders
LIMIT 3

"""

df = pd.read_sql(sql_query, con=engine)
df
# Out:
#    OrderID CustomerID  EmployeeID   OrderDate RequiredDate ShippedDate  \
# 0    10248      VINET           5  1996-07-04   1996-08-01  1996-07-16
# 1    10249      TOMSP           6  1996-07-05   1996-08-16  1996-07-10
# 2    10250      HANAR           4  1996-07-08   1996-08-05  1996-07-12
#
#    ShipVia  Freight                   ShipName         ShipAddress  \
# 0        3    32.38  Vins et alcools Chevalier  59 rue de l'Abbaye
# 1        1    11.61         Toms Spezialitäten       Luisenstr. 48
# 2        2    65.83              Hanari Carnes     Rua do Paço, 67
#
#          ShipCity ShipRegion ShipPostalCode ShipCountry
# 0           Reims       None          51100      France
# 1         Münster       None          44087     Germany
# 2  Rio de Janeiro         RJ      05454-876      Brazil

# %%
sql_query="""
SELECT *
FROM products
LIMIT 3

"""

df = pd.read_sql(sql_query, con=engine)
df
# Out:
#    ProductID    ProductName  SupplierID  CategoryID      QuantityPerUnit  \
# 0          1           Chai           8           1   10 boxes x 30 bags
# 1          2          Chang           1           1   24 - 12 oz bottles
# 2          3  Aniseed Syrup           1           2  12 - 550 ml bottles
#
#    UnitPrice  UnitsInStock  UnitsOnOrder  ReorderLevel  Discontinued
# 0       18.0            39             0            10             1
# 1       19.0            17            40            25             1
# 2       10.0            13            70            25             0

# %%
sql_query="""
SELECT *
FROM usstates
LIMIT 3

"""

df = pd.read_sql(sql_query, con=engine)
df
# Out:
#    StateID StateName StateAbbr StateRegion
# 0        1   Alabama        AL       south
# 1        2    Alaska        AK       north
# 2        3   Arizona        AZ        west

# %% [markdown]
# As you can see, some tables (like `usstates` or `region`) contain information that is probably less prone to change than other tables (like `orders` or `order_details`). This database is well organized to avoid unnecessary duplication. Let's start digging deeper in the data.

# %% [markdown]
# ## 2: Products
#
# What products is this company selling? The `products` and `categories` tables contain information to answer this question.
#
# Use a combination of SQL queries and Pandas merge to answer the following questions:
#
# - What categories of products is the company selling?
# - How many products per category does the catalog contain?
# - Let's focus only on products that have not been discontinued => how many products per category?
# - What are the most expensive 5 products (not discontinued)?
# - How many units of each of these 5 products are there in stock?
# - Draw a pie chart of the categories, with slices that have the size of the number of products in that category (use non discontinued products)

# %% [markdown]
# ### 2.a: What categories of products is the company selling?
#
# Remember that PostgreSQL is case sensitive.

# %%
sql_query="""
SELECT *
FROM products

"""

df = pd.read_sql(sql_query, con=engine)
df.CategoryID.unique()
# Out:
# array([1, 2, 7, 6, 8, 4, 3, 5])

# %% [markdown]
# ### 2.b: How many products per category does the catalog contain?
#
# Keep in mind that you can cast a %sql result to a pandas dataframe using the `.DataFrame()` method.

# %%
sql_query="""
SELECT "CategoryID", COUNT(*)
FROM products
GROUP BY "CategoryID"

"""

df = pd.read_sql(sql_query, con=engine)
df
# Out:
#    CategoryID  count
# 0           6      6
# 1           4     10
# 2           8     12
# 3           5      7
# 4           1     12
# 5           2     12
# 6           7      5
# 7           3     13

# %% [markdown]
# ### 2.c: How many not discontinued products per category?

# %%
sql_query="""
SELECT "CategoryID", COUNT("Discontinued")
FROM products
GROUP BY "CategoryID"

"""

df = pd.read_sql(sql_query, con=engine)
df
# Out:
#    CategoryID  count
# 0           6      6
# 1           4     10
# 2           8     12
# 3           5      7
# 4           1     12
# 5           2     12
# 6           7      5
# 7           3     13

# %% [markdown]
# ### 2.d: What are the most expensive 5 products (not discontinued)?

# %%
sql_query="""
SELECT "CategoryID", COUNT(*)
FROM products
GROUP BY "CategoryID"

"""

df = pd.read_sql(sql_query, con=engine)
df

# %% [markdown]
# ### 2.e: How many units of each of these 5 products are there in stock?

# %%
sql_query="""
SELECT "UnitPrice", "ProductName"
FROM products
WHERE "Discontinued" = 0
ORDER BY "UnitPrice" DESC
LIMIT 5

"""

df = pd.read_sql(sql_query, con=engine)
df
# Out:
#    UnitPrice             ProductName
# 0      263.5           Côte de Blaye
# 1       81.0  Sir Rodney's Marmalade
# 2       62.5        Carnarvon Tigers
# 3       55.0    Raclette Courdavault
# 4       53.0   Manjimup Dried Apples

# %% [markdown]
# ### 2.f: Pie Chart
#
# Use pandas to make a pie chart plot.

# %%
import seaborn as sns
sns.barplot(df.ProductName, df.UnitPrice)

# %% [markdown]
# ## 3: Orders
#
# Now that we have a better understanding of products, let's start digging into orders.
#
# - How many orders in total?
# - How many orders per year
# - How many orders per quarter
# - Which country is receiving the most orders
# - Which country is receiving the least
# - What's the average shipping time (ShippedDate - OrderDate)
# - What customer is submitting the highest number of orders?
# - What customer is generating the highest revenue (need to pd.merge with order_details)
# - What fraction of the revenue is generated by the top 5 customers?

# %%
# Out:
# 830

# %% [markdown]
# ### 3.a: How many orders in total?

# %%
sql_query="""
SELECT "OrderID"
FROM orders
GROUP BY "OrderID"

"""

df = pd.read_sql(sql_query, con=engine)
len(df.OrderID)
# Out:
# 830

# %% [markdown]
# ### 3.b: How many orders per year?

# %%
sql_query="""
SELECT EXTRACT(YEAR FROM "OrderDate") AS "Year", COUNT(*)
FROM orders
GROUP BY "Year"

"""

df = pd.read_sql(sql_query, con=engine)
df
# Out:
#      Year  count
# 0  1997.0    408
# 1  1998.0    270
# 2  1996.0    152

# %% [markdown]
# ### 3.c: How many orders per quarter?
#
# Make a line plot for these.

# %%
sql_query="""
SELECT EXTRACT(YEAR FROM "OrderDate") AS "Year", COUNT(*)
FROM orders
GROUP BY "Year"

"""

df = pd.read_sql(sql_query, con=engine)
df

# %% [markdown]
# ### 3.d: Which country is receiving the most orders?

# %%
sql_query="""
SELECT "ShipCountry", COUNT(*)
FROM orders
GROUP BY "ShipCountry"
ORDER BY "count" DESC
limit 1

"""

df = pd.read_sql(sql_query, con=engine)
df
# Out:
#   ShipCountry  count
# 0     Germany    122

# %% [markdown]
# ### 3.e: Which country is receiving the least?

# %%
sql_query="""
SELECT "ShipCountry", COUNT(*)
FROM orders
GROUP BY "ShipCountry"
ORDER BY "count" 
limit 1

"""

df = pd.read_sql(sql_query, con=engine)
df
# Out:
#   ShipCountry  count
# 0      Norway      6

# %% [markdown]
# ### 3.f: What's the average shipping time (ShippedDate - OrderDate)?

# %%
sql_query="""
SELECT AVG("ShippedDate"-"OrderDate")
FROM orders


"""

df = pd.read_sql(sql_query, con=engine)
df
# Out:
#         avg
# 0  8.491965

# %% [markdown]
# ### 3.g: What customer is submitting the highest number of orders?

# %%
sql_query="""
SELECT "CustomerID", COUNT(*)
FROM orders
GROUP BY "CustomerID"
ORDER BY "count" DESC



"""

df = pd.read_sql(sql_query, con=engine)
df
# Out:
#    CustomerID  count
# 0       SAVEA     31
# 1       ERNSH     30
# 2       QUICK     28
# 3       HUNGO     19
# 4       FOLKO     19
# 5       HILAA     18
# 6       BERGS     18
# 7       RATTC     18
# 8       BONAP     17
# 9       FRANK     15
# 10      WARTH     15
# 11      LEHMS     15
# 12      BOTTM     14
# 13      HANAR     14
# 14      LILAS     14
# 15      LAMAI     14
# 16      WHITC     14
# 17      KOENE     14
# 18      QUEEN     13
# 19      AROUT     13
# 20      MEREP     13
# 21      SUPRD     12
# 22      REGGC     12
# 23      LINOD     12
# 24      VAFFE     11
# 25      GREAL     11
# 26      BLONP     11
# 27      RICAR     11
# 28      WANDK     10
# 29      VICTE     10
# ..        ...    ...
# 59      PERIC      6
# 60      TRADH      6
# 61      DRACD      6
# 62      TOMSP      6
# 63      MORGK      5
# 64      HUNGC      5
# 65      VINET      5
# 66      GALED      5
# 67      RANCH      5
# 68      COMMI      5
# 69      ROMEY      5
# 70      OCEAN      5
# 71      FOLIG      5
# 72      PRINI      5
# 73      LETSS      4
# 74      ANATR      4
# 75      SPECD      4
# 76      DUMON      4
# 77      LACOR      4
# 78      THEBI      4
# 79      BOLID      3
# 80      LAUGB      3
# 81      TRAIH      3
# 82      FRANR      3
# 83      THECR      3
# 84      CONSH      3
# 85      NORTS      3
# 86      LAZYK      2
# 87      GROSR      2
# 88      CENTC      1
#
# [89 rows x 2 columns]

# %% [markdown]
# ### 3.h: What customer is generating the highest revenue (need to pd.merge with order_details)?

# %%
sql_query="""
SELECT *
FROM orders
LIMIT 2

"""

df = pd.read_sql(sql_query, con=engine)
df
# Out:
#    OrderID CustomerID  EmployeeID   OrderDate RequiredDate ShippedDate  \
# 0    10248      VINET           5  1996-07-04   1996-08-01  1996-07-16
# 1    10249      TOMSP           6  1996-07-05   1996-08-16  1996-07-10
#
#    ShipVia  Freight                   ShipName         ShipAddress ShipCity  \
# 0        3    32.38  Vins et alcools Chevalier  59 rue de l'Abbaye    Reims
# 1        1    11.61         Toms Spezialitäten       Luisenstr. 48  Münster
#
#   ShipRegion ShipPostalCode ShipCountry
# 0       None          51100      France
# 1       None          44087     Germany

# %%
sql_query="""
SELECT *
FROM products
LIMIT 2

"""

df = pd.read_sql(sql_query, con=engine)
df
# Out:
#    ProductID ProductName  SupplierID  CategoryID     QuantityPerUnit  \
# 0          1        Chai           8           1  10 boxes x 30 bags
# 1          2       Chang           1           1  24 - 12 oz bottles
#
#    UnitPrice  UnitsInStock  UnitsOnOrder  ReorderLevel  Discontinued
# 0       18.0            39             0            10             1
# 1       19.0            17            40            25             1

# %%
sql_query="""
SELECT *
FROM order_details
LIMIT 2

"""

df = pd.read_sql(sql_query, con=engine)
df
# Out:
#    OrderID  ProductID  UnitPrice  Quantity  Discount
# 0    10248         11       14.0        12       0.0
# 1    10248         42        9.8        10       0.0

# %%
sql_query="""

SELECT "OrderID", "sum", CustomerID.orders
FROM(    SELECT "OrderID", SUM("Revenue")
        FROM (SELECT "OrderID", "ProductID", ("UnitPrice"*"Quantity") AS "Revenue"
        FROM order_details) as sub
    GROUP BY "OrderID") as sub1
INNER JOIN orders
ON 




"""

df = pd.read_sql(sql_query, con=engine)
df
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-147-93cab2e0354d> in <module>()
#      14 """
#      15
# ---> 16 df = pd.read_sql(sql_query, con=engine)
#      17 df
#
# /Users/tyronewilliams/anaconda/envs/dsi/lib/python2.7/site-packages/pandas/io/sql.pyc in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     513             sql, index_col=index_col, params=params,
#     514             coerce_float=coerce_float, parse_dates=parse_dates,
# --> 515             chunksize=chunksize)
#     516
#     517
#
# /Users/tyronewilliams/anaconda/envs/dsi/lib/python2.7/site-packages/pandas/io/sql.pyc in read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize)
#    1188         args = _convert_params(sql, params)
#    1189
# -> 1190         result = self.execute(*args)
#    1191         columns = result.keys()
#    1192
#
# /Users/tyronewilliams/anaconda/envs/dsi/lib/python2.7/site-packages/pandas/io/sql.pyc in execute(self, *args, **kwargs)
#    1079     def execute(self, *args, **kwargs):
#    1080         """Simple passthrough to SQLAlchemy connectable"""
# -> 1081         return self.connectable.execute(*args, **kwargs)
#    1082
#    1083     def read_table(self, table_name, index_col=None, coerce_float=True,
#
# /Users/tyronewilliams/anaconda/envs/dsi/lib/python2.7/site-packages/sqlalchemy/engine/base.pyc in execute(self, statement, *multiparams, **params)
#    1989
#    1990         connection = self.contextual_connect(close_with_result=True)
# -> 1991         return connection.execute(statement, *multiparams, **params)
#    1992
#    1993     def scalar(self, statement, *multiparams, **params):
#
# /Users/tyronewilliams/anaconda/envs/dsi/lib/python2.7/site-packages/sqlalchemy/engine/base.pyc in execute(self, object, *multiparams, **params)
#     904         """
#     905         if isinstance(object, util.string_types[0]):
# --> 906             return self._execute_text(object, multiparams, params)
#     907         try:
#     908             meth = object._execute_on_connection
#
# /Users/tyronewilliams/anaconda/envs/dsi/lib/python2.7/site-packages/sqlalchemy/engine/base.pyc in _execute_text(self, statement, multiparams, params)
#    1052             statement,
#    1053             parameters,
# -> 1054             statement, parameters
#    1055         )
#    1056         if self._has_events or self.engine._has_events:
#
# /Users/tyronewilliams/anaconda/envs/dsi/lib/python2.7/site-packages/sqlalchemy/engine/base.pyc in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1144                 parameters,
#    1145                 cursor,
# -> 1146                 context)
#    1147
#    1148         if self._has_events or self.engine._has_events:
#
# /Users/tyronewilliams/anaconda/envs/dsi/lib/python2.7/site-packages/sqlalchemy/engine/base.pyc in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1339                 util.raise_from_cause(
#    1340                     sqlalchemy_exception,
# -> 1341                     exc_info
#    1342                 )
#    1343             else:
#
# /Users/tyronewilliams/anaconda/envs/dsi/lib/python2.7/site-packages/sqlalchemy/util/compat.pyc in raise_from_cause(exception, exc_info)
#     200     exc_type, exc_value, exc_tb = exc_info
#     201     cause = exc_value if exc_value is not exception else None
# --> 202     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     203
#     204 if py3k:
#
# /Users/tyronewilliams/anaconda/envs/dsi/lib/python2.7/site-packages/sqlalchemy/engine/base.pyc in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1137                         statement,
#    1138                         parameters,
# -> 1139                         context)
#    1140         except Exception as e:
#    1141             self._handle_dbapi_exception(
#
# /Users/tyronewilliams/anaconda/envs/dsi/lib/python2.7/site-packages/sqlalchemy/engine/default.pyc in do_execute(self, cursor, statement, parameters, context)
#     448
#     449     def do_execute(self, cursor, statement, parameters, context=None):
# --> 450         cursor.execute(statement, parameters)
#     451
#     452     def do_execute_no_params(self, cursor, statement, context=None):
#
# ProgrammingError: (psycopg2.ProgrammingError) unterminated quoted identifier at or near ""Order
#
#
#
#
# "
# LINE 9: ON "Order
#            ^
#  [SQL: '\n\nSELECT "OrderID", "sum", CustomerID.orders\nFROM(    SELECT "OrderID", SUM("Revenue")\n        FROM (SELECT "OrderID", "ProductID", ("UnitPrice"*"Quantity") AS "Revenue"\n        FROM order_details) as sub\n    GROUP BY "OrderID") as sub1\nINNER JOIN orders\nON "Order\n\n\n\n\n']

# %% [markdown]
# ### 3.i: What fraction of the revenue is generated by the top 5 customers?
#
# Compare that with the fraction represented by 5 customers over the total number of customers.

# %% [markdown]
# Wow!! 5.5% of the customers generate a third of the revenue!!

# %% [markdown]
# ## Bonus: Other tables
#
# Investigate the content of other tables. In particular lookt at the `suppliers`, `shippers` and `employees` tables.
